# %%
## arguments


if __name__ == "__main__":
    pyspark_bin_path = "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3"
    python_path = "/home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/bin/python39"
    app_name = "social media"
    data_path = "/home/pc/Assignment/SocialMedia/Main/output/sample.csv"
    hdfs_working_path = "hdfs://10.123.51.78:8020/user/social_media/"
    malay_stopword_path = "/home/pc/Assignment/node_modules/stopwords-ms/stopwords-ms.json"
    jieba_replace_csv = "/home/pc/Assignment/SocialMedia/Main/replacement.csv"
    hdfsHost = "hdfs://10.123.51.78"
    hdfsPort = "8020"
    hdfs_working_path_file = "/user/social_media/"
    hiveWarehouseDirectory = "hdfs://10.123.51.78:8020/user/hive/warehouse"
    hiveTriftServerAddress = "thrift://g2.bigtop.it:9083"
    remove_outliers = False


    import shutil
    import os
    import json
    import findspark
    findspark.init(pyspark_bin_path)
    from FileIO import *
    import utilities as u
    import pyspark
    from Preprocessing import *
    from pyspark.sql import SparkSession
    from DetectLanguage import *
    from LangAgg import *
    from WordCount import *
    from pyspark.sql.window import Window
    from nltk.corpus import stopwords
    from FilterOutliers import *
    from postagChinese import *
    from JiebaTagToStandardTag import *
    from SegmentDataframe import *
    from PosTagBMBI import *
    from Alternator import *
    from TokenLanguageReplaceTool import *
    from pyspark.ml.feature import NGram
    from KeyGram import *
    from MiddleKey import *
    import matplotlib.pyplot as plt
    import math

    ################################################################################################################
    ## initialize spark session
    os.environ["HADOOP_USER_NAME"] = "hdfs"
    os.environ["PYSPARK_PYTHON"] = python_path
    os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.12:3.3.0  pyspark-shell'


    spark = SparkSession.builder \
        .master("local[*]") \
        .appName(app_name) \
        .config("spark.driver.memory", "70g")\
        .config("spark.sql.warehouse.dir", hiveWarehouseDirectory) \
        .config("spark.sql.catalogImplementation", "hive")\
        .config("hive.metastore.uris", hiveTriftServerAddress)\
        .getOrCreate()

    ###################################################################################################################################################################################
    ## convert original data to avro file
    csv = spark.read.csv(data_path, header = 'true')
    try:
        remove_from_hdfs(hdfs_working_path+"original_data.avro", header = 'true')
    except:
        pass
    csv.write.format("avro").mode("overwrite").save(hdfs_working_path+"original_data.avro", header = 'true')
    ###################################################################################################################################################################################
    ## preprocessing I : remove the token that will disturb the sentence tokenization
    df = read_avro(spark, hdfs_working_path+"original_data.avro")
    p1 = preprocess_for_token_with_dot_delimeter(df)

    print("==========DATA WITH REDUCE DELEMITER INTERFERE==========")
    write_avro(p1, hdfs_working_path+"reduce_delimeter_disturbance.avro")
    remove_from_hdfs(hdfs_working_path+"original_data.avro")
    print(">>> saved reduce delimeter and removed original......")
    ###################################################################################################################################################################################
    ## preprocessing II : sentence tokenization
    df = read_avro(spark, hdfs_working_path+"reduce_delimeter_disturbance.avro")

    engSent = get_eng_senDF(df)
    engSent= engSent.withColumn("text", explode(engSent.columns[0])).select("text")
    chiSent = get_df_chiSen(df)
    chiSent = chiSent.withColumn("text", explode(chiSent.columns[0]))

    print("==========DATA WITH SENTENCE TOKENIZATION==========")
    write_avro(chiSent, hdfs_working_path+"sent_tokenize.avro")
    remove_from_hdfs(hdfs_working_path+"reduce_delimeter_disturbance.avro")
    print(">>> saved sent tokenize and remove reduce tokenize......")
    ###################################################################################################################################################################################
    ## preprocessing III : remove unwanted data, language independent
    df = read_avro(spark, hdfs_working_path+"sent_tokenize.avro")
    p3 = preprocessing(df, "text")

    print("==========DATA WITHOUT UNWANTED DATA==========")
    write_avro(p3, hdfs_working_path+"without_unwanted.avro")
    remove_from_hdfs(hdfs_working_path+"sent_tokenize.avro")
    print(">>> saved without unwanted and remove sent tokenize......")
    ###################################################################################################################################################################################
    ## Classify Language
    df = read_avro(spark, hdfs_working_path+"without_unwanted.avro")
    df = df.repartition(74)
    withLanguage = df.withColumn("lang", detectUDF(col("text"))) ## detectUDF is custom made UDF

    print("==========DATA WITH LANGUAGE==========")
    write_avro(withLanguage, hdfs_working_path+"with_language.avro")
    remove_from_hdfs(hdfs_working_path+"without_unwanted.avro")
    print(">>> saved with language and remove unwanted......")
    ###################################################################################################################################################################################
    ## Convert chinese character to simplified version
    df = read_avro(spark, hdfs_working_path+"with_language.avro")
    simpChi = df.withColumn("text", udfSimpChinese(col("text")))

    print("==========CHINESE SIMPLIFIED DATA==========")
    write_avro(simpChi, hdfs_working_path+"chinese_simplified.avro")
    remove_from_hdfs(hdfs_working_path+"with_language.avro")
    print(">>> saved with simplified chinese and remove with language......")
    ###################################################################################################################################################################################
    ## Classify the dataframe to several languages
    df = read_avro(spark, hdfs_working_path+"chinese_simplified.avro")
    agg = LanguageAggregor(df, "lang")
    print("these dataset have languages : " + str(agg.all_language))
    visualize_languages(agg)
    por = None
    for i in agg.all_language:
        if i != "None":
            if por == None:
                por = agg.get_lang_dataframe(i)
            else:
                por = unionAll(por, agg.get_lang_dataframe(i))

    print("==========CHINESE, ENGLISH & MALAY DATA==========")            
    write_avro(por, hdfs_working_path+"bmbcbiOnly")
    remove_from_hdfs(hdfs_working_path+"chinese_simplified.avro")
    print(">>> saved with bmbibc only and remove chinese_simplified......")
    ###################################################################################################################################################################################
    ## Word Count
    df = read_avro(spark, hdfs_working_path+"bmbcbiOnly")
    wc = get_wc_df(df)
    vocabLang =  wc.withColumn('wordLang', detectUDF(col('word')))
    vocabLang \
        .select("word","word_count", row_number() \
        .over(Window.partitionBy() \
                .orderBy(desc(vocabLang['word_count']))) \
        .alias("id"), "wordLang")

    print("==========WORD COUNT WITH STOPWORDS==========")
    write_avro(vocabLang, hdfs_working_path+"vocabLangFull")
    ###################################################################################################################################################################################
    ## Word Count Without Stopwords
    malayStopWords = set(json.load(open(malay_stopword_path)))
    stopwordsSet = set(stopwords.words('english') + stopwords.words('chinese') ).union(malayStopWords)
    reg =   ["^"+x+"$" for x in stopwordsSet]
    reg = "|".join(reg)
    df = read_avro(spark, hdfs_working_path+"vocabLangFull")
    regex = "|".join(list(stopwordsSet)) 
    noStopwords = df.filter(~df.word.rlike(reg))
    noStopwords = noStopwords.select("word","word_count", row_number().over(Window.partitionBy() \
      .orderBy(desc(df['word_count']))).alias("id"))

    print("==========WORD COUNT WITHOUT STOPWORDS==========")
    write_avro(noStopwords, hdfs_working_path+"no_stopwords")
    read_avro(spark, hdfs_working_path+"no_stopwords").show(1000, False)
    ###################################################################################################################################################################################
    ## Select topics
    keys = []
    want_choose = True
    while want_choose:
        key = input("enter keyword : ")
        keys.append(key)
        decision = input("Again? (y / n) :  ")
        if not (decision.upper() == 'Y' or decision.upper() == 'YES'):
            want_choose = False
    print("your selected keys is " + str(keys))
    ###################################################################################################################################################################################
    df = read_avro(spark, hdfs_working_path+"bmbcbiOnly")
    regex = "|".join(keys)
    withKeys = df.filter( df.text.rlike(regex))

    print("==========FILTER SENTENCE BY KEYS==========")
    write_avro(withKeys, hdfs_working_path+"sentence_with_keys")
    ###################################################################################################################################################################################
    df = read_avro(spark, hdfs_working_path+"sentence_with_keys")
    with_statistics = df.withColumn("token", u.tokenize_chineseDF(df.text))
    with_statistics = with_statistics.withColumn("length", size(with_statistics.token))
    df = with_statistics.select("text", "length", "lang")

    print("==========SENTENCE WITH WORD COUNT==========")
    write_avro(df, hdfs_working_path+"sentence_with_statistics")
    remove_from_hdfs(hdfs_working_path+"sentence_with_keys")
    ###################################################################################################################################################################################
    s = read_avro(spark, hdfs_working_path+"sentence_with_statistics")

    if remove_outliers:
        s = s.coalesce(74)

        bc = s.filter( (s.lang == "Language.CHINESE") & (s.length > 3))
        bm = s.filter( (s.lang == "Language.MALAY") &  (s.length > 3))
        bi = s.filter( (s.lang == "Language.ENGLISH") &  (s.length > 3))

        bc = bc.coalesce(74)
        bm = bm.coalesce(74)
        bi = bi.coalesce(74)

        bcC = bc.select(bc.length)
        bmC = bm.select(bm.length)
        biC = bi.select(bi.length)

        print("MALAY BOX PLOT")
        bmC.toPandas().plot.box()
        plt.show()

        print("ENGLISH BOX PLOT")
        biC.toPandas().plot.box()
        plt.show()

        print("CHINESE BOX PLOT")
        bcC.toPandas().plot.box()
        plt.show()
        ###################################################################################################################################################################################
        nobc = None
        nobm = None
        nobi = None

        if bc.count() != 0 :
            obc = find_outliers(bc)
            nobc = obc.filter((obc.total_outliers < 1) & (obc.length > 3))
            bcC = nobc.select(nobc.length)

        if bi.count() != 0 :
            obi = find_outliers(bi)
            nobi = obi.filter((obi.total_outliers < 1)  & (obi.length > 3))
            biC = nobi.select(nobi.length)

        if bm.count() != 0 :
            obm = find_outliers(bm)
            nobm = obm.filter((obm.total_outliers < 1)  & (obm.length > 3))
            bmC = nobm.select(nobm.length)

        x = [nobc, nobi, nobm]
        noNone = [x for x in x if x != None]


        print("MALAY BOX PLOT REMOVE OUTLIER")
        bmC.toPandas().plot.box()
        plt.show()


        print("ENGLISH BOX PLOT REMOVE OUTLIER")
        biC.toPandas().plot.box()
        plt.show()


        print("CHINESE BOX PLOT REMOVE OUTLIER")
        bcC.toPandas().plot.box()
        plt.show()


        df = unionAll(*noNone).drop("token").drop("length").drop("total_outliers")
        print("==========SENTENCE WITHOUT OUTLIERS==========")
    else:
        df = s

    write_avro(df, hdfs_working_path+"sentence_without_out")
    ###################################################################################################################################################################################
    # Pos tagging
    df = read_avro(spark, hdfs_working_path+"sentence_without_out")
    bc = df.filter(df.lang == "Language.CHINESE")
    # Pos tagging chinese
    if bc.count() > 0:
        chineseTag = bc.withColumn("chinese_tag", udfTagChinese(bc.text))

        chineseTag = chineseTag.rdd.map(lambda x : (x.text, x.chinese_tag[0], x.chinese_tag[1], x.lang)).\
            toDF(["original","token","chinese_tag", "language"])

        init_replacement_dict(jieba_replace_csv)

        withNormalTag = chineseTag.withColumn("tag", stdTokenUDF(col("chinese_tag")))\
            .withColumn("language", lit("chinese"))
    ###################################################################################################################################################################################
    # Pos tagging english and malay
    bmbi = df.filter( (df.lang == "Language.ENGLISH") | (df.lang == "Language.MALAY"))

    if bmbi.count() > 0:
        bmbi = u.assign_id_column(bmbi)

    numberOfRows = bmbi.count()
    splitInto = math.ceil(bmbi.count()/1000)
    segments = get_segments(bmbi, splitInto)

    print(f"the file is splitted into {splitInto} files to ease the prcessing")

    ## split to smaller file to easier processing
    for i in range(splitInto):
        write_avro(segments[i], f"{hdfs_working_path}IN/{i}")

    for i in range(splitInto):
        df = read_avro(spark, f"{hdfs_working_path}IN/{i}")
        tag = df.withColumn("tag", posUDF(df.text))
        write_avro(tag, f"{hdfs_working_path}/OUT/{i}")  

    sc = spark.sparkContext
    os.system(f"hdfs dfs -rm -r {hdfs_working_path_file}IN")

    ## merge the file to one and remove the out directory
    alt = Alternator()

    for i in range(splitInto):
        if i == 0:
            merge = read_avro(spark, f"{hdfs_working_path}/OUT/{i}")
            write_avro(merge, f"{hdfs_working_path}/Merge/{alt.num}")
        else:
            merge = read_avro(spark, f"{hdfs_working_path}/Merge/{alt.num}")
            df = read_avro(spark, f"{hdfs_working_path}/OUT/{i}")
            union = unionAll(merge, df)
            alt.alternate()
            write_avro(union, f"{hdfs_working_path}/Merge/{alt.num}")
            remove_from_hdfs(f"{hdfs_working_path}/Merge/{alt.get_alternate()}")

    os.system(f"hdfs dfs -rm -r {hdfs_working_path_file}OUT")        
    df = read_avro(spark, f"{hdfs_working_path}/Merge/{alt.num}")
    ###################################################################################################################################################################################
    df = df.rdd.map(lambda x : (x.text, x.tag[0], x.tag[1], x.lang)).\
            toDF(["original","token","tag", "language"])

    merged = df.unionByName(withNormalTag, allowMissingColumns=True)
    print("==========FRAME WITH TAG AND TOKEN==========")
    write_avro(merged, f"{hdfs_working_path}tokenAndTag")
    os.system(f"hdfs dfs -rm -r {hdfs_working_path_file}Merge")        
    df = read_avro(spark, f"{hdfs_working_path}tokenAndTag")
    print("removed merge and saved token And Tag")
    ###################################################################################################################################################################################
    ## Preparing token with languages label using joining
    words = \
    df.rdd.flatMap(lambda x : x.token) \
    .map(lambda x : (x,1)) \
    .toDF(["words"]) \
    .drop("_2")

    uniqueWords = words.select('words').distinct()

    wL= read_avro(spark, hdfs_working_path+"vocabLangFull")
    wL = wL.drop("word_count").drop("id")

    withPreDetected = uniqueWords.join(wL, wL.word ==  uniqueWords.words,"left").drop("word")

    ## null set is those without languages
    nullSet = withPreDetected.filter(withPreDetected.wordLang.isNull())
    notNullSet = withPreDetected.filter(~withPreDetected.wordLang.isNull())
    corrected = nullSet.withColumn("wordLang", detectUDF(nullSet.words))


    print("==========TOKENS WITH LANGUAGES ASSOCIATED==========")
    write_avro(unionAll(corrected, notNullSet), hdfs_working_path+"replacement_token_lang")
    ###################################################################################################################################################################################
    tokenLang = read_avro(spark, hdfs_working_path+"replacement_token_lang")
    df = read_avro(spark, f"{hdfs_working_path}tokenAndTag")
    tokenLang = tokenLang.withColumn("wordLang" ,regexp_replace("wordLang","None|error", "oov"))
    correct_dict = tokenLang

    engSet = correct_dict.filter(correct_dict.wordLang.rlike("Language.ENGLISH"))
    bmSet =correct_dict.filter(correct_dict.wordLang.rlike("Language.MALAY"))
    bcSet = correct_dict.filter(correct_dict.wordLang.rlike("Language.CHINESE"))
    oovSet = correct_dict.filter(~correct_dict.wordLang.rlike("Language.MALAY|Language.CHINESE|Language.ENGLISH"))

    oov = set(oovSet.rdd.flatMap(lambda x : x).collect())
    bi = set(engSet.rdd.flatMap(lambda x : x).collect())
    bm = set(bmSet.rdd.flatMap(lambda x : x).collect())
    bc = set(bcSet.rdd.flatMap(lambda x : x).collect())

    replacement = [bi, bm, bc, oov]
    languages = ["en","ms","zh","oov"]

    tokenToLanguage = TokenLanguageReplaceTool(replacement, languages)
    withLang = df.withColumn("language_pattern", tokenToLanguage.getLangUDF(col("token")))
    print("==========DATAFRAME WITH LANG, TOKEN AND TAG==========")
    write_avro(withLang, f"{hdfs_working_path}tokenAndTagAndLang")
    remove_from_hdfs(f"{hdfs_working_path}tokenAndTag")
    print("removed token and tag saved token, tag, and lang")
    ###################################################################################################################################################################################
    ## creating N-gram for token, language and tagging
    a = read_avro(spark, f"{hdfs_working_path}tokenAndTagAndLang")
    a = a.withColumn("sentence_id", monotonically_increasing_id())

    ## bigram
    tokenNgram =NGram(n=2, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=2, inputCol="tag", outputCol="tag_gram")
    langNgram =NGram(n=2, inputCol="language_pattern", outputCol="lang_gram")

    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)
    n2 = langNgram.transform(n2)

    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram", "lang_gram"))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag", \
            "language_pattern","token", posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag", \
            "language_pattern", "pos",col("col.token_gram"), col("col.tag_gram"),  col("col.lang_gram"))

    print("==========CREATED BIGRAM==========")
    write_avro(t, f"{hdfs_working_path}N2_GRAM")
    print("save bigram")
    ###################################################################################################################################################################################
    ## trigram
    tokenNgram =NGram(n=3, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=3, inputCol="tag", outputCol="tag_gram")
    langNgram =NGram(n=3, inputCol="language_pattern", outputCol="lang_gram")

    n = tokenNgram.transform(a)
    n = tagNgram.transform(n)
    n = langNgram.transform(n)

    t = n.withColumn("tmp", arrays_zip("token_gram", "tag_gram", "lang_gram"))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag", \
            "language_pattern","token", posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag", \
            "language_pattern", "pos",col("col.token_gram"), col("col.tag_gram"),  col("col.lang_gram"))

    print("==========CREATED TRIGRAM==========")
    write_avro(t, f"{hdfs_working_path}N3_GRAM")
    print("save trigram")
    ###################################################################################################################################################################################
    ## 4 gram
    tokenNgram =NGram(n=4, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=4, inputCol="tag", outputCol="tag_gram")
    langNgram =NGram(n=4, inputCol="language_pattern", outputCol="lang_gram")

    n = tokenNgram.transform(a)
    n = tagNgram.transform(n)
    n = langNgram.transform(n)

    t = n.withColumn("tmp", arrays_zip("token_gram", "tag_gram", "lang_gram"))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag",\
            "language_pattern","token", posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag", \
            "language_pattern", "pos",col("col.token_gram"), col("col.tag_gram"),  col("col.lang_gram"))

    print("==========CREATED 4-GRAM==========")
    write_avro(t, f"{hdfs_working_path}N4_GRAM")
    print("save n4 gram")
    ###################################################################################################################################################################################
    ## 5 gram
    tokenNgram =NGram(n=5, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=5, inputCol="tag", outputCol="tag_gram")
    langNgram =NGram(n=5, inputCol="language_pattern", outputCol="lang_gram")

    n = tokenNgram.transform(a)
    n = tagNgram.transform(n)
    n = langNgram.transform(n)

    t = n.withColumn("tmp", arrays_zip("token_gram", "tag_gram", "lang_gram"))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag",\
            "language_pattern","token", posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag","language", "token", "chinese_tag",\
            "language_pattern", "pos",col("col.token_gram"), col("col.tag_gram"),  col("col.lang_gram"))

    print("==========CREATED 5-GRAM==========")
    write_avro(t, f"{hdfs_working_path}N5_GRAM")
    print("save n5 gram")
    ###################################################################################################################################################################################
    ## assign gram type and merge
    g2 = read_avro(spark, f"{hdfs_working_path}N2_GRAM")
    g3 = read_avro(spark, f"{hdfs_working_path}N3_GRAM")
    g4 = read_avro(spark, f"{hdfs_working_path}N4_GRAM")
    g5 = read_avro(spark, f"{hdfs_working_path}N5_GRAM")

    g2 = g2.withColumn("gram_type", lit("2"))
    g3 = g3.withColumn("gram_type", lit("3"))
    g4 = g4.withColumn("gram_type", lit("4"))
    g5 = g5.withColumn("gram_type", lit("5"))

    merge = unionAll(g2, g3, g4, g5)

    print("==========ASSEMBLE ALL NGRAM==========")
    write_avro(merge, f"{hdfs_working_path}ALL_GRAM")

    remove_from_hdfs(f"{hdfs_working_path}N2_GRAM")
    remove_from_hdfs(f"{hdfs_working_path}N3_GRAM")
    remove_from_hdfs(f"{hdfs_working_path}N4_GRAM")
    remove_from_hdfs(f"{hdfs_working_path}N5_GRAM")

    print("remove single gram and save merge gram")
    ###################################################################################################################################################################################
    # get the n-gram that contain the keywords only
    df = read_avro(spark, f"{hdfs_working_path}ALL_GRAM")
    keys = set(keys)
    keyGramFilter = KeyGram(keys)
    withKeyOnly = keyGramFilter.getDFwithKeywordsOnly(df)
    print("==========GET NGRAM WITH KEYWORDS ONLY==========")
    write_avro(withKeyOnly, f"{hdfs_working_path}KeyOnlyData")
    ###################################################################################################################################################################################
    # create the column to identify whether keyword at middle
    df = read_avro(spark,  f"{hdfs_working_path}KeyOnlyData")
    mid = MiddleKey(keys)
    withMiddleFlag = df.withColumn("middle_key", mid.middleUDF(df.gram_type, df.token_gram))
    print("==========MARK THE NGRAM WITH KEYWORDS MIDDLE ON IT==========")
    write_avro(withMiddleFlag, f"{hdfs_working_path}MiddleFlagData")
    remove_from_hdfs(f"{hdfs_working_path}KeyOnlyData")
    print("remove keyword only and save with center flag")
    ###################################################################################################################################################################################
    # Frequency statistics
    # language pattern frequency statistics
    df = read_avro(spark,  f"{hdfs_working_path}MiddleFlagData")
    langFreq = df.groupBy("lang_gram").count().withColumnRenamed("count", "lang_gram_f")
    write_avro(langFreq, f"{hdfs_working_path}langFreq")
    langFreq = read_avro(spark, f"{hdfs_working_path}langFreq")
    mergeLangF = df.join(langFreq, df.lang_gram == langFreq.lang_gram).drop(langFreq.lang_gram)
    print("==========DF WITH LANG GRAM FREQUENCY==========")
    write_avro(mergeLangF, f"{hdfs_working_path}MergelangFreq")
    remove_from_hdfs(f"{hdfs_working_path}langFreq")
    ###################################################################################################################################################################################
    # token pattern frequency statistics
    df = read_avro(spark, f"{hdfs_working_path}MergelangFreq")
    tokenFreq = df.groupBy("token_gram").count().withColumnRenamed("count", "token_gram_f")
    write_avro(tokenFreq, f"{hdfs_working_path}tokenFreq")
    tokenFreq = read_avro(spark, f"{hdfs_working_path}tokenFreq")
    mergeTokenF = df.join(tokenFreq, df.token_gram == tokenFreq.token_gram).drop(tokenFreq.token_gram)
    print("==========DF WITH TOKEN FREQUENCY==========")
    write_avro(mergeTokenF, f"{hdfs_working_path}MergeTokenFreq")
    remove_from_hdfs(f"{hdfs_working_path}tokenFreq")
    remove_from_hdfs(f"{hdfs_working_path}MergelangFreq")
    ###################################################################################################################################################################################
    # tag pattern frequency statistics
    df = read_avro(spark, f"{hdfs_working_path}MergeTokenFreq")
    tagGramFreq = df.groupBy("tag_gram").count().withColumnRenamed("count", "tag_gram_f")
    write_avro(tagGramFreq, f"{hdfs_working_path}WithTagGramFreq")
    tf = read_avro(spark, f"{hdfs_working_path}WithTagGramFreq")
    withtagF = df.join(tf, df.tag_gram == tf.tag_gram).drop(tf.tag_gram)
    print("==========DF WITH TAG GRAM FREQUENCY==========")
    write_avro(withtagF, f"{hdfs_working_path}WithTagFreq")
    remove_from_hdfs(f"{hdfs_working_path}WithTagGramFreq")
    remove_from_hdfs(f"{hdfs_working_path}MergeTokenFreq")
    ###################################################################################################################################################################################
    # normalize into two table before store into hive
    # gram table & original data
    df = read_avro(spark, f"{hdfs_working_path}WithTagFreq")
    df =df.repartition(800)

    print("if disk block error happen, need increase the repartition value")

    gram_table = \
        df.select("sentence_id", "pos", "token_gram", "token_gram_f", \
                  "tag_gram", "tag_gram_f", "lang_gram", "lang_gram_f", \
                  "gram_type", "middle_key", "language")

    gram_table = gram_table.withColumn("uniqueID", monotonically_increasing_id())

    print("==========GETTING GRAM TABLE==========")
    write_avro(gram_table, f"{hdfs_working_path}gram_table")

    originalSentence  = df.dropDuplicates((['sentence_id'])) \
        .select("sentence_id", "original", "tag", \
                "language", "token", "chinese_tag", "language_pattern")

    originalSentence = originalSentence.withColumn("uniqueID", monotonically_increasing_id())

    print("==========GETTING SOURCE TABLE==========")
    write_avro(originalSentence, f"{hdfs_working_path}source_data")
    ###################################################################################################################################################################################
    # save into hive table
    spark.sql("drop database if exists social_media_db cascade;")
    spark.sql("create database social_media_db;")


    original = read_avro(spark, f"{hdfs_working_path}source_data")
    gram_table = read_avro(spark, f"{hdfs_working_path}gram_table")


    original.write\
    .format("orc") \
    .mode("overwrite") \
    .saveAsTable("social_media_db.source_data")


    gram_table.write\
    .format("orc") \
    .mode("overwrite") \
    .saveAsTable("social_media_db.gram_table")
    ###################################################################################################################################################################################
    # analytics : Top 10 Common Language Pattern
    spark.sql("use social_media_db;")

    Q="""
    select
        distinct lang_gram,
        lang_gram_f
    from
        gram_table
    order by
        lang_gram_f DESC limit 10;
    """

    SMLang = spark.sql(Q).toPandas()

    fig, ax = plt.subplots(1,1,figsize=(15,5))

    x = SMLang['lang_gram'][:10].tolist()
    y = SMLang['lang_gram_f'][:10].tolist()
    ax.barh(x,y)
    ax.set_title('Top 10 Most Common Language Patterns in Social Media Data')
    for index, value in enumerate(y):
        ax.text(value, index,
                 str(value))
    ax.invert_yaxis()

    plt.show()


    ###################################################################################################################################################################################
    # analytics : Top 10 Common Pos Pattern

    Q="""
    select
        distinct tag_gram,
        tag_gram_f
    from
        gram_table
    order by
        tag_gram_f DESC limit 10;
    """

    SMPos = spark.sql(Q).toPandas()



    fig, ax = plt.subplots(1,1,figsize=(15,5))

    x = SMPos['tag_gram'][:10].tolist()
    y = SMPos['tag_gram_f'][:10].tolist()
    ax.barh(x,y)
    ax.set_title('Top 10 Most Common POS Patterns in Social Media Data')
    for index, value in enumerate(y):
        ax.text(value, index,
                 str(value))
    ax.invert_yaxis()

    plt.show()

    ###################################################################################################################################################################################
    # analytics : Top 10 Common token Pattern

    Q="""
    select
        distinct token_gram,
        token_gram_f
    from
        gram_table
    order by
        token_gram_f DESC limit 10;
    """

    SMtok = spark.sql(Q).toPandas()

    fig, ax = plt.subplots(1,1,figsize=(15,5))

    x = SMtok['token_gram'][:10].tolist()
    y = SMtok['token_gram_f'][:10].tolist()
    ax.barh(x,y)
    ax.set_title('Top 10 Most Common Token Patterns in Social Media Data')
    for index, value in enumerate(y):
        ax.text(value, index,
                 str(value))
    ax.invert_yaxis()

    plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Using state  server backend.
# 2022-10-11 08:29:43.263655: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya_boilerplate/frozen_graph.py:35: UserWarning: Cannot import beam_search_ops from Tensorflow Addons, ['malaya.jawi_rumi.deep_model', 'malaya.phoneme.deep_model', 'malaya.rumi_jawi.deep_model', 'malaya.stem.deep_model'] will not available to use, make sure Tensorflow Addons version >= 0.12.0
#   warnings.warn(
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya_boilerplate/frozen_graph.py:38: UserWarning: check compatible Tensorflow version with Tensorflow Addons at https://github.com/tensorflow/addons/releases
#   warnings.warn(
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya/tokenizer.py:208: FutureWarning: Possible nested set at position 3372
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya/tokenizer.py:208: FutureWarning: Possible nested set at position 3890
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))
# Warning: Ignoring non-Spark config property: hive.metastore.uris
# :: loading settings :: url = jar:file:/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/pc/.ivy2/cache
# The jars for the packages stored in: /home/pc/.ivy2/jars
# org.apache.spark#spark-avro_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-35efd265-d3da-42b0-a4a2-e8557a2489f2;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-avro_2.12;3.3.0 in central
# 	found org.tukaani#xz;1.8 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# :: resolution report :: resolve 129ms :: artifacts dl 4ms
# 	:: modules in use:
# 	org.apache.spark#spark-avro_2.12;3.3.0 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.tukaani#xz;1.8 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-35efd265-d3da-42b0-a4a2-e8557a2489f2
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/3ms)
# 22/10/11 08:29:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/11 08:29:49 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 22/10/11 08:29:49 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 22/10/11 08:29:49 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 22/10/11 08:29:49 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 22/10/11 08:29:49 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# ==========DATA WITH REDUCE DELEMITER INTERFERE==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/original_data.avro
# >>> saved reduce delimeter and removed original......
# ==========DATA WITH SENTENCE TOKENIZATION==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/reduce_delimeter_disturbance.avro
# >>> saved sent tokenize and remove reduce tokenize......
# ==========DATA WITHOUT UNWANTED DATA==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/sent_tokenize.avro
# >>> saved without unwanted and remove sent tokenize......
# ==========DATA WITH LANGUAGE==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/without_unwanted.avro
# >>> saved with language and remove unwanted......
# ==========CHINESE SIMPLIFIED DATA==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/with_language.avro
# >>> saved with simplified chinese and remove with language......
# these dataset have languages : ['Language.MALAY', 'Language.ENGLISH', 'Language.CHINESE']
# ==========CHINESE, ENGLISH & MALAY DATA==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/chinese_simplified.avro
# >>> saved with bmbibc only and remove chinese_simplified......
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.044 seconds.                                 (0 + 19) / 19]
# Prefix dict has been built successfully.
# Loading model cost 1.051 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.052 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.076 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.102 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.111 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.118 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.066 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.122 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.066 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.110 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.121 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.123 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.125 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.125 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.033 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.037 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.034 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.038 seconds.
# Prefix dict has been built successfully.
# ==========WORD COUNT WITH STOPWORDS==========
# ==========WORD COUNT WITHOUT STOPWORDS==========
# 22/10/11 08:30:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:30:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:30:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:30:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:30:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +--------------+----------+----+
# |word          |word_count|id  |
# +--------------+----------+----+
# |good          |322       |1   |
# |seller        |285       |2   |
# |很            |204       |3   |
# |好            |161       |4   |
# |tq            |160       |5   |
# |delivery      |133       |6   |
# |sampai        |131       |7   |
# |赞            |126       |8   |
# |barang        |123       |9   |
# |fast          |121       |10  |
# |小            |103       |11  |
# |饼            |102       |12  |
# |ok            |102       |13  |
# |xd            |102       |14  |
# |凤            |99        |15  |
# |beli          |94        |16  |
# |received      |90        |17  |
# |dah           |87        |18  |
# |sangat        |82        |19  |
# |thank         |78        |20  |
# |ni            |76        |21  |
# |penghantaran  |74        |22  |
# |pun           |70        |23  |
# |cantik        |68        |24  |
# |quality       |68        |25  |
# |order         |67        |26  |
# |nice          |67        |27  |
# |terima        |65        |28  |
# |都            |64        |29  |
# |字            |63        |30  |
# |秒            |62        |31  |
# |cepat         |62        |32  |
# |处            |61        |33  |
# |念            |61        |34  |
# |cuan          |61        |35  |
# |四声          |61        |36  |
# |爨            |61        |37  |
# |repeat        |58        |38  |
# |product       |57        |39  |
# |吃            |57        |40  |
# |condition     |56        |41  |
# |收到          |55        |42  |
# |yg            |54        |43  |
# |kasih         |54        |44  |
# |tak           |52        |45  |
# |thanks        |50        |46  |
# |dgn           |49        |47  |
# |买            |49        |48  |
# |je            |48        |49  |
# |tapi          |46        |50  |
# |谢谢          |44        |51  |
# |kain          |44        |52  |
# |packaging     |43        |53  |
# |murah         |40        |54  |
# |alias         |39        |55  |
# |item          |39        |56  |
# |不错          |39        |57  |
# |会            |39        |58  |
# |bad           |39        |59  |
# |包装          |38        |60  |
# |还            |38        |61  |
# |卖家          |38        |62  |
# |recommended   |36        |63  |
# |la            |36        |64  |
# |pakai         |36        |65  |
# |selamat       |35        |66  |
# |service       |35        |67  |
# |money         |34        |68  |
# |value         |34        |69  |
# |喜欢          |33        |70  |
# |好吃          |33        |71  |
# |sgt           |32        |72  |
# |laju          |31        |73  |
# |x             |31        |74  |
# |okay          |30        |75  |
# |pantas        |30        |76  |
# |kualiti       |30        |77  |
# |time          |30        |78  |
# |tu            |29        |79  |
# |很快          |29        |80  |
# |love          |29        |81  |
# |n             |28        |82  |
# |不            |28        |83  |
# |sbb           |28        |84  |
# |dlm           |28        |85  |
# |smpai         |28        |86  |
# |selesa        |28        |87  |
# |nak           |27        |88  |
# |hati          |27        |89  |
# |mmg           |27        |90  |
# |dh            |27        |91  |
# |kena          |27        |92  |
# |best          |26        |93  |
# |满意          |26        |94  |
# |nk            |26        |95  |
# |well          |26        |96  |
# |kemas         |26        |97  |
# |rm            |26        |98  |
# |快            |25        |99  |
# |brg           |25        |100 |
# |puas          |25        |101 |
# |东西          |24        |102 |
# |suka          |24        |103 |
# |dia           |24        |104 |
# |utk           |23        |105 |
# |try           |23        |106 |
# |memang        |23        |107 |
# |berbaloi      |23        |108 |
# |sikit         |23        |109 |
# |真的          |23        |110 |
# |购买          |22        |111 |
# |灬            |22        |112 |
# |gambar        |21        |113 |
# |lah           |21        |114 |
# |服务          |21        |115 |
# |太            |21        |116 |
# |bagus         |21        |117 |
# |alhamdulillah |21        |118 |
# |sedap         |21        |119 |
# |lg            |21        |120 |
# |size          |21        |121 |
# |没            |20        |122 |
# |kat           |20        |123 |
# |nanti         |20        |124 |
# |guna          |20        |125 |
# |速度          |19        |126 |
# |free          |19        |127 |
# |再            |19        |128 |
# |到货          |19        |129 |
# |pon           |19        |130 |
# |sesuai        |19        |131 |
# |回购          |19        |132 |
# |much          |18        |133 |
# |video         |18        |134 |
# |buy           |18        |135 |
# |also          |18        |136 |
# |saiz          |18        |137 |
# |baju          |17        |138 |
# |sy            |17        |139 |
# |人            |17        |140 |
# |sorry         |17        |141 |
# |哒            |17        |142 |
# |kalau         |17        |143 |
# |price         |17        |144 |
# |tebal         |16        |145 |
# |great         |16        |146 |
# |说            |16        |147 |
# |ngam          |16        |148 |
# |mcm           |16        |149 |
# |senang        |16        |150 |
# |buat          |16        |151 |
# |tp            |16        |152 |
# |包裹          |16        |153 |
# |物流          |15        |154 |
# |lembut        |15        |155 |
# |bila          |15        |156 |
# |worth         |15        |157 |
# |货物          |15        |158 |
# |发货          |15        |159 |
# |elok          |15        |160 |
# |sebab         |15        |161 |
# |看            |15        |162 |
# |质量          |15        |163 |
# |很多          |14        |164 |
# |才            |14        |165 |
# |items         |14        |166 |
# |gift          |14        |167 |
# |packing       |14        |168 |
# |agak          |14        |169 |
# |warna         |14        |170 |
# |辔            |14        |171 |
# |值得          |14        |172 |
# |one           |13        |173 |
# |parcel        |13        |174 |
# |商家          |13        |175 |
# |便宜          |13        |176 |
# |超            |13        |177 |
# |shopee        |13        |178 |
# |去            |13        |179 |
# |希望          |13        |180 |
# |第二          |13        |181 |
# |下单          |13        |182 |
# |pos           |13        |183 |
# |时间          |13        |184 |
# |第一          |13        |185 |
# |super         |12        |186 |
# |星            |12        |187 |
# |l             |12        |188 |
# |货            |12        |189 |
# |still         |12        |190 |
# |beg           |12        |191 |
# |想            |12        |192 |
# |kasut         |12        |193 |
# |一点          |12        |194 |
# |hope          |12        |195 |
# |material      |12        |196 |
# |next          |12        |197 |
# |cuma          |12        |198 |
# |said          |12        |199 |
# |感觉          |12        |200 |
# |下次          |12        |201 |
# |really        |12        |202 |
# |smpi          |11        |203 |
# |shipping      |11        |204 |
# |bungkusan     |11        |205 |
# |everything    |11        |206 |
# |香            |11        |207 |
# |days          |11        |208 |
# |lgi           |11        |209 |
# |lawa          |11        |210 |
# |蛮            |11        |211 |
# |cm            |11        |212 |
# |号            |11        |213 |
# |好喝          |11        |214 |
# |get           |11        |215 |
# |送货          |11        |216 |
# |lama          |11        |217 |
# |做            |11        |218 |
# |味道          |11        |219 |
# |mengena       |11        |220 |
# |一个          |10        |221 |
# |可爱          |10        |222 |
# |cheap         |10        |223 |
# |wrap          |10        |224 |
# |thankyou      |10        |225 |
# |mask          |10        |226 |
# |价钱          |10        |227 |
# |lambat        |10        |228 |
# |rasa          |10        |229 |
# |快递          |10        |230 |
# |trusted       |10        |231 |
# |损坏          |10        |232 |
# |第一次        |10        |233 |
# |overall       |10        |234 |
# |大            |10        |235 |
# |死            |10        |236 |
# |like          |10        |237 |
# |哈哈哈        |10        |238 |
# |态度          |10        |239 |
# |betul         |10        |240 |
# |ank           |10        |241 |
# |nipis         |9         |242 |
# |safely        |9         |243 |
# |bought        |9         |244 |
# |邮寄          |9         |245 |
# |design        |9         |246 |
# |jam           |9         |247 |
# |bag           |9         |248 |
# |价格          |9         |249 |
# |推荐          |9         |250 |
# |terbaikkk     |9         |251 |
# |kedai         |9         |252 |
# |面            |9         |253 |
# |天            |9         |254 |
# |h             |9         |255 |
# |产品          |9         |256 |
# |盒子          |9         |257 |
# |完好          |9         |258 |
# |harap         |9         |259 |
# |cpt           |9         |260 |
# |喝            |9         |261 |
# |好好          |9         |262 |
# |secure        |9         |263 |
# |got           |9         |264 |
# |muat          |9         |265 |
# |panas         |9         |266 |
# |excellent     |9         |267 |
# |喔            |9         |268 |
# |kotak         |9         |269 |
# |macam         |9         |270 |
# |arrived       |9         |271 |
# |开心          |9         |272 |
# |ng            |9         |273 |
# |完            |9         |274 |
# |出货          |9         |275 |
# |oder          |9         |276 |
# |日期          |8         |277 |
# |pkai          |8         |278 |
# |cukup         |8         |279 |
# |goodgood      |8         |280 |
# |need          |8         |281 |
# |品质          |8         |282 |
# |à             |8         |283 |
# |want          |8         |284 |
# |ye            |8         |285 |
# |little        |8         |286 |
# |bit           |8         |287 |
# |purchase      |8         |288 |
# |nd            |8         |289 |
# |far           |8         |290 |
# |pulak         |8         |291 |
# |hesteg        |8         |292 |
# |donat         |8         |293 |
# |一分          |8         |294 |
# |月            |8         |295 |
# |爱            |8         |296 |
# |后            |8         |297 |
# |bubble        |8         |298 |
# |jnt           |8         |299 |
# |org           |8         |300 |
# |ambil         |8         |301 |
# |好评          |8         |302 |
# |easy          |8         |303 |
# |saller        |8         |304 |
# |nh            |8         |305 |
# |tqvm          |8         |306 |
# |berkualiti    |8         |307 |
# |很久          |8         |308 |
# |ê             |8         |309 |
# |set           |8         |310 |
# |could         |8         |311 |
# |笑            |8         |312 |
# |dpt           |8         |313 |
# |二次          |7         |314 |
# |点            |7         |315 |
# |letak         |7         |316 |
# |台湾          |7         |317 |
# |机会          |7         |318 |
# |better        |7         |319 |
# |第二次        |7         |320 |
# |mantap        |7         |321 |
# |iteemuu       |7         |322 |
# |c             |7         |323 |
# |laa           |7         |324 |
# |pretty        |7         |325 |
# |adit          |7         |326 |
# |fit           |7         |327 |
# |cute          |7         |328 |
# |pn            |7         |329 |
# |last          |7         |330 |
# |视频          |7         |331 |
# |这次          |7         |332 |
# |receive       |7         |333 |
# |long          |7         |334 |
# |中            |7         |335 |
# |semoga        |7         |336 |
# |gandhi        |7         |337 |
# |辣            |7         |338 |
# |kaitan        |7         |339 |
# |takde         |7         |340 |
# |不好          |7         |341 |
# |朋友          |7         |342 |
# |biru          |7         |343 |
# |channel       |7         |344 |
# |kg            |7         |345 |
# |diterima      |7         |346 |
# |nnti          |7         |347 |
# |小孩          |7         |348 |
# |新            |7         |349 |
# |colour        |7         |350 |
# |颜色          |7         |351 |
# |cntik         |7         |352 |
# |美食          |7         |353 |
# |products      |7         |354 |
# |tahan         |7         |355 |
# |comel         |7         |356 |
# |奶茶          |6         |357 |
# |已            |6         |358 |
# |老板          |6         |359 |
# |放            |6         |360 |
# |珍珠          |6         |361 |
# |儿子          |6         |362 |
# |hrga          |6         |363 |
# |蛋            |6         |364 |
# |货品          |6         |365 |
# |食            |6         |366 |
# |布料          |6         |367 |
# |马来          |6         |368 |
# |job           |6         |369 |
# |kene          |6         |370 |
# |pasang        |6         |371 |
# |小时          |6         |372 |
# |shop          |6         |373 |
# |box           |6         |374 |
# |kaki          |6         |375 |
# |sempat        |6         |376 |
# |大马          |6         |377 |
# |粉            |6         |378 |
# |适合          |6         |379 |
# |不知          |6         |380 |
# |无损          |6         |381 |
# |seluar        |6         |382 |
# |cannot        |6         |383 |
# |padu          |6         |384 |
# |高            |6         |385 |
# |slow          |6         |386 |
# |unlocked      |6         |387 |
# |color         |6         |388 |
# |值            |6         |389 |
# |terlalu       |6         |390 |
# |nasib         |6         |391 |
# |expected      |6         |392 |
# |satisfied     |6         |393 |
# |grab          |6         |394 |
# |ship          |6         |395 |
# |完好无损      |6         |396 |
# |berfungsi     |6         |397 |
# |有机          |6         |398 |
# |sound         |6         |399 |
# |超级          |6         |400 |
# |name          |6         |401 |
# |express       |6         |402 |
# |way           |6         |403 |
# |us            |6         |404 |
# |give          |6         |405 |
# |trbaik        |6         |406 |
# |包            |6         |407 |
# |ambik         |6         |408 |
# |terbaikk      |6         |409 |
# |tudung        |6         |410 |
# |high          |6         |411 |
# |nampak        |6         |412 |
# |use           |6         |413 |
# |first         |6         |414 |
# |penjual       |6         |415 |
# |perfect       |6         |416 |
# |gila          |6         |417 |
# |kecik         |6         |418 |
# |物品          |6         |419 |
# |州            |6         |420 |
# |hantar        |6         |421 |
# |还要          |6         |422 |
# |新鲜          |6         |423 |
# |bootloader    |6         |424 |
# |twrpor        |6         |425 |
# |不到          |6         |426 |
# |ask           |6         |427 |
# |packed        |6         |428 |
# |来说          |6         |429 |
# |phone         |6         |430 |
# |xde           |6         |431 |
# |cuba          |6         |432 |
# |harini        |6         |433 |
# |day           |6         |434 |
# |拍            |5         |435 |
# |烧            |5         |436 |
# |aku           |5         |437 |
# |berat         |5         |438 |
# |layanan       |5         |439 |
# |天下          |5         |440 |
# |bg            |5         |441 |
# |tk            |5         |442 |
# |star          |5         |443 |
# |buying        |5         |444 |
# |digunakan     |5         |445 |
# |年            |5         |446 |
# |政府          |5         |447 |
# |tpi           |5         |448 |
# |wangi         |5         |449 |
# |late          |5         |450 |
# |少            |5         |451 |
# |big           |5         |452 |
# |taste         |5         |453 |
# |salah         |5         |454 |
# |jangkitan     |5         |455 |
# |hb            |5         |456 |
# |bawak         |5         |457 |
# |yet           |5         |458 |
# |soon          |5         |459 |
# |tengok        |5         |460 |
# |date          |5         |461 |
# |漂亮          |5         |462 |
# |blh           |5         |463 |
# |nt            |5         |464 |
# |讲            |5         |465 |
# |有损          |5         |466 |
# |最            |5         |467 |
# |美            |5         |468 |
# |kerosakan     |5         |469 |
# |cheaper       |5         |470 |
# |新年          |5         |471 |
# |不用          |5         |472 |
# |biasa         |5         |473 |
# |jadi          |5         |474 |
# |would         |5         |475 |
# |install       |5         |476 |
# |豚            |5         |477 |
# |benda         |5         |478 |
# |stokin        |5         |479 |
# |okey          |5         |480 |
# |badan         |5         |481 |
# |rezeki        |5         |482 |
# |hadiah        |5         |483 |
# |棒            |5         |484 |
# |food          |5         |485 |
# |baby          |5         |486 |
# |越            |5         |487 |
# |g             |5         |488 |
# |main          |5         |489 |
# |宝宝          |5         |490 |
# |肥肥          |5         |491 |
# |quite         |5         |492 |
# |jahitan       |5         |493 |
# |ja            |5         |494 |
# |鱼            |5         |495 |
# |nie           |5         |496 |
# |pembungkusan  |5         |497 |
# |kurang        |5         |498 |
# |kt            |5         |499 |
# |know          |5         |500 |
# |simpan        |5         |501 |
# |comfortable   |5         |502 |
# |保护          |5         |503 |
# |cover         |5         |504 |
# |sale          |5         |505 |
# |looks         |5         |506 |
# |maaf          |5         |507 |
# |da            |5         |508 |
# |already       |5         |509 |
# |different     |5         |510 |
# |goood         |5         |511 |
# |中国          |5         |512 |
# |装好          |5         |513 |
# |top           |5         |514 |
# |wear          |5         |515 |
# |ô             |4         |516 |
# |ắ             |4         |517 |
# |钱            |4         |518 |
# |多多          |4         |519 |
# |live          |4         |520 |
# |内            |4         |521 |
# |tv            |4         |522 |
# |bentuk        |4         |523 |
# |wait          |4         |524 |
# |broken        |4         |525 |
# |医院          |4         |526 |
# |装            |4         |527 |
# |一分钱一      |4         |528 |
# |生产          |4         |529 |
# |里            |4         |530 |
# |punya         |4         |531 |
# |ikut          |4         |532 |
# |光顾          |4         |533 |
# |year          |4         |534 |
# |app           |4         |535 |
# |破损          |4         |536 |
# |介绍          |4         |537 |
# |竟然          |4         |538 |
# |开            |4         |539 |
# |好像          |4         |540 |
# |dngn          |4         |541 |
# |cun           |4         |542 |
# |这家          |4         |543 |
# |post          |4         |544 |
# |马来西亚      |4         |545 |
# |multilanguage |4         |546 |
# |ita           |4         |547 |
# |problem       |4         |548 |
# |好多          |4         |549 |
# |芝麻          |4         |550 |
# |穿            |4         |551 |
# |送到          |4         |552 |
# |茶            |4         |553 |
# |sekali        |4         |554 |
# |kh            |4         |555 |
# |ủ             |4         |556 |
# |破            |4         |557 |
# |covid         |4         |558 |
# |很美          |4         |559 |
# |厉害          |4         |560 |
# |actually      |4         |561 |
# |ckup          |4         |562 |
# |tuk           |4         |563 |
# |affordable    |4         |564 |
# |may           |4         |565 |
# |ư             |4         |566 |
# |ii            |4         |567 |
# |klu           |4         |568 |
# |online        |4         |569 |
# |ikan          |4         |570 |
# |一分货        |4         |571 |
# |tr            |4         |572 |
# |artist        |4         |573 |
# |deal          |4         |574 |
# |lighting      |4         |575 |
# |always        |4         |576 |
# |let           |4         |577 |
# |even          |4         |578 |
# |two           |4         |579 |
# |balik         |4         |580 |
# |sedikit       |4         |581 |
# |tau           |4         |582 |
# |玩            |4         |583 |
# |几天          |4         |584 |
# |看起来        |4         |585 |
# |西亚          |4         |586 |
# |amik          |4         |587 |
# |ya            |4         |588 |
# |方便面        |4         |589 |
# |王            |4         |590 |
# |感谢          |4         |591 |
# |一分钱        |4         |592 |
# |较慢          |4         |593 |
# |快速          |4         |594 |
# |li            |4         |595 |
# |看起          |4         |596 |
# |jenis         |4         |597 |
# |work          |4         |598 |
# |recommend     |4         |599 |
# |店家          |4         |600 |
# |亲嘴          |4         |601 |
# |tranh         |4         |602 |
# |kad           |4         |603 |
# |eng           |4         |604 |
# |soo           |4         |605 |
# |terbaikkkk    |4         |606 |
# |damage        |4         |607 |
# |准            |4         |608 |
# |简单          |4         |609 |
# |setakat       |4         |610 |
# |de            |4         |611 |
# |byk           |4         |612 |
# |ragu          |4         |613 |
# |adjust        |4         |614 |
# |youu          |4         |615 |
# |ala           |4         |616 |
# |刚            |4         |617 |
# |实惠          |4         |618 |
# |ì             |4         |619 |
# |speed         |4         |620 |
# |快收          |4         |621 |
# |ringan        |4         |622 |
# |行动党        |4         |623 |
# |superb        |4         |624 |
# |zip           |4         |625 |
# |bintang       |4         |626 |
# |掉            |4         |627 |
# |pecah         |4         |628 |
# |takda         |4         |629 |
# |switch        |4         |630 |
# |friends       |4         |631 |
# |responsive    |4         |632 |
# |newborn       |4         |633 |
# |works         |4         |634 |
# |j             |4         |635 |
# |分享          |4         |636 |
# |锅            |4         |637 |
# |煮            |4         |638 |
# |比较慢        |4         |639 |
# |时            |4         |640 |
# |puting        |4         |641 |
# |habis         |4         |642 |
# |maybe         |4         |643 |
# |越来越        |4         |644 |
# |etc           |4         |645 |
# |coffee        |4         |646 |
# |took          |4         |647 |
# |bli           |4         |648 |
# |刚好          |4         |649 |
# |服务态度      |4         |650 |
# |回            |4         |651 |
# |辛苦          |4         |652 |
# |投票          |4         |653 |
# |出            |4         |654 |
# |penghantran   |4         |655 |
# |skin          |4         |656 |
# |customer      |4         |657 |
# |sarung        |4         |658 |
# |选择          |4         |659 |
# |影片          |4         |660 |
# |quan          |4         |661 |
# |uryeon        |4         |662 |
# |kuat          |4         |663 |
# |within        |4         |664 |
# |mall          |4         |665 |
# |越来          |4         |666 |
# |cectshop      |4         |667 |
# |shoppe        |4         |668 |
# |这款          |4         |669 |
# |舒服          |4         |670 |
# |soft          |4         |671 |
# |bau           |4         |672 |
# |memuaskan     |4         |673 |
# |bantal        |4         |674 |
# |仔            |4         |675 |
# |严实          |4         |676 |
# |马            |4         |677 |
# |吵            |4         |678 |
# |gmbar         |4         |679 |
# |bos           |4         |680 |
# |win           |4         |681 |
# |came          |4         |682 |
# |half          |4         |683 |
# |anda          |4         |684 |
# |esp           |4         |685 |
# |courier       |4         |686 |
# |农            |4         |687 |
# |戴            |4         |688 |
# |分钱          |4         |689 |
# |hehe          |4         |690 |
# |semuanya      |4         |691 |
# |还好          |4         |692 |
# |jeee          |4         |693 |
# |brang         |4         |694 |
# |put           |4         |695 |
# |small         |4         |696 |
# |suami         |4         |697 |
# |兔            |3         |698 |
# |刚刚          |3         |699 |
# |新年快乐      |3         |700 |
# |cantikk       |3         |701 |
# |dimurahkan    |3         |702 |
# |awesome       |3         |703 |
# |response      |3         |704 |
# |饿            |3         |705 |
# |花            |3         |706 |
# |another       |3         |707 |
# |looking       |3         |708 |
# |working       |3         |709 |
# |asal          |3         |710 |
# |pendek        |3         |711 |
# |cari          |3         |712 |
# |friendly      |3         |713 |
# |住            |3         |714 |
# |小时候        |3         |715 |
# |吹            |3         |716 |
# |油            |3         |717 |
# |tenkiu        |3         |718 |
# |到达          |3         |719 |
# |旅游          |3         |720 |
# |risiko        |3         |721 |
# |card          |3         |722 |
# |shown         |3         |723 |
# |plastic       |3         |724 |
# |week          |3         |725 |
# |things        |3         |726 |
# |ngan          |3         |727 |
# |watch         |3         |728 |
# |划算          |3         |729 |
# |整理          |3         |730 |
# |pro           |3         |731 |
# |车            |3         |732 |
# |repeated      |3         |733 |
# |penang        |3         |734 |
# |offer         |3         |735 |
# |碎            |3         |736 |
# |糖            |3         |737 |
# |差            |3         |738 |
# |报到          |3         |739 |
# |没什么        |3         |740 |
# |接种          |3         |741 |
# |箱子          |3         |742 |
# |credit        |3         |743 |
# |camera        |3         |744 |
# |support       |3         |745 |
# |selalu        |3         |746 |
# |korang        |3         |747 |
# |胖            |3         |748 |
# |kancil        |3         |749 |
# |mkn           |3         |750 |
# |家人          |3         |751 |
# |chai          |3         |752 |
# |test          |3         |753 |
# |时代          |3         |754 |
# |神            |3         |755 |
# |只能          |3         |756 |
# |沉            |3         |757 |
# |天天          |3         |758 |
# |发            |3         |759 |
# |谢            |3         |760 |
# |才能          |3         |761 |
# |compatible    |3         |762 |
# |times         |3         |763 |
# |think         |3         |764 |
# |bunyi         |3         |765 |
# |sang          |3         |766 |
# |check         |3         |767 |
# |duit          |3         |768 |
# |tangan        |3         |769 |
# |hujung        |3         |770 |
# |take          |3         |771 |
# |甜            |3         |772 |
# |商品          |3         |773 |
# |占            |3         |774 |
# |想象          |3         |775 |
# |男            |3         |776 |
# |brownlee      |3         |777 |
# |says          |3         |778 |
# |kn            |3         |779 |
# |months        |3         |780 |
# |lone          |3         |781 |
# |old           |3         |782 |
# |dkt           |3         |783 |
# |dekat         |3         |784 |
# |bibir         |3         |785 |
# |tiptop        |3         |786 |
# |beautifull    |3         |787 |
# |工作          |3         |788 |
# |客服          |3         |789 |
# |q             |3         |790 |
# |洗            |3         |791 |
# |青蛙          |3         |792 |
# |公道          |3         |793 |
# |身体          |3         |794 |
# |keep          |3         |795 |
# |mrwhosetheboss|3         |796 |
# |arrive        |3         |797 |
# |世人          |3         |798 |
# |review        |3         |799 |
# |definitely    |3         |800 |
# |ordered       |3         |801 |
# |using         |3         |802 |
# |面包          |3         |803 |
# |火腿          |3         |804 |
# |文            |3         |805 |
# |心            |3         |806 |
# |薯条          |3         |807 |
# |mahal         |3         |808 |
# |sent          |3         |809 |
# |价格便宜      |3         |810 |
# |man           |3         |811 |
# |suitable      |3         |812 |
# |original      |3         |813 |
# |wrapping      |3         |814 |
# |event         |3         |815 |
# |hahaha        |3         |816 |
# |sejuk         |3         |817 |
# |masuk         |3         |818 |
# |jarang        |3         |819 |
# |评论          |3         |820 |
# |放心          |3         |821 |
# |女儿          |3         |822 |
# |果            |3         |823 |
# |乐            |3         |824 |
# |订            |3         |825 |
# |pembukusan    |3         |826 |
# |tgok          |3         |827 |
# |hard          |3         |828 |
# |picture       |3         |829 |
# |lasak         |3         |830 |
# |平安          |3         |831 |
# |退款          |3         |832 |
# |煎            |3         |833 |
# |疫苗          |3         |834 |
# |优惠          |3         |835 |
# |生产日期      |3         |836 |
# |卖            |3         |837 |
# |该是          |3         |838 |
# |expiry        |3         |839 |
# |respond       |3         |840 |
# |rickrolling   |3         |841 |
# |due           |3         |842 |
# |random        |3         |843 |
# |pilih         |3         |844 |
# |k             |3         |845 |
# |码            |3         |846 |
# |tkde          |3         |847 |
# |made          |3         |848 |
# |buka          |3         |849 |
# |真好          |3         |850 |
# |lew           |3         |851 |
# |tukar         |3         |852 |
# |bru           |3         |853 |
# |advertised    |3         |854 |
# |spicy         |3         |855 |
# |che           |3         |856 |
# |bole          |3         |857 |
# |tadi          |3         |858 |
# |祝            |3         |859 |
# |快乐          |3         |860 |
# |盒            |3         |861 |
# |上海          |3         |862 |
# |台湾省        |3         |863 |
# |贤            |3         |864 |
# |好赚          |3         |865 |
# |干            |3         |866 |
# |twitter       |3         |867 |
# |beautiful     |3         |868 |
# |psg           |3         |869 |
# |calar         |3         |870 |
# |香港          |3         |871 |
# |坏            |3         |872 |
# |集            |3         |873 |
# |食物          |3         |874 |
# |bisa          |3         |875 |
# |klau          |3         |876 |
# |两个          |3         |877 |
# |st            |3         |878 |
# |oled          |3         |879 |
# |janji         |3         |880 |
# |fits          |3         |881 |
# |mur           |3         |882 |
# |sambal        |3         |883 |
# |打开          |3         |884 |
# |你好          |3         |885 |
# |dress         |3         |886 |
# |晚上          |3         |887 |
# |麦当劳        |3         |888 |
# |司机          |3         |889 |
# |comfy         |3         |890 |
# |youtuber      |3         |891 |
# |fixture       |3         |892 |
# |longgar       |3         |893 |
# |hot           |3         |894 |
# |kevin         |3         |895 |
# |code          |3         |896 |
# |girl          |3         |897 |
# |risau         |3         |898 |
# |家庭          |3         |899 |
# |孩子          |3         |900 |
# |运输          |3         |901 |
# |支持          |3         |902 |
# |星期          |3         |903 |
# |出兵          |3         |904 |
# |投票站        |3         |905 |
# |second        |3         |906 |
# |light         |3         |907 |
# |可惜          |3         |908 |
# |km            |3         |909 |
# |kok           |3         |910 |
# |只            |3         |911 |
# |升            |3         |912 |
# |真            |3         |913 |
# |gmbr          |3         |914 |
# |peramah       |3         |915 |
# |videos        |3         |916 |
# |deliver       |3         |917 |
# |services      |3         |918 |
# |marques       |3         |919 |
# |book          |3         |920 |
# |cermin        |3         |921 |
# |bju           |3         |922 |
# |laptop        |3         |923 |
# |莫            |3         |924 |
# |送            |3         |925 |
# |挺            |3         |926 |
# |tahu          |3         |927 |
# |budget        |3         |928 |
# |药材          |3         |929 |
# |memory        |3         |930 |
# |lmbt          |3         |931 |
# |follow        |3         |932 |
# |correct       |3         |933 |
# |甲            |3         |934 |
# |虾米          |3         |935 |
# |卫生          |3         |936 |
# |comment       |3         |937 |
# |咯            |3         |938 |
# |pic           |3         |939 |
# |rest          |3         |940 |
# |sekolah       |3         |941 |
# |drink         |3         |942 |
# |骂            |3         |943 |
# |地方          |3         |944 |
# |干净          |3         |945 |
# |店            |3         |946 |
# |ᥬ             |3         |947 |
# |装得          |3         |948 |
# |西都          |3         |949 |
# |shopping      |3         |950 |
# |see           |3         |951 |
# |going         |3         |952 |
# |cuci          |3         |953 |
# |sangattt      |3         |954 |
# |wrna          |3         |955 |
# |hand          |3         |956 |
# |好看          |3         |957 |
# |everyone      |3         |958 |
# |公司          |3         |959 |
# |美国          |3         |960 |
# |约            |3         |961 |
# |明天          |3         |962 |
# |hp            |3         |963 |
# |lalu          |3         |964 |
# |rd            |3         |965 |
# |媒体          |3         |966 |
# |medical       |3         |967 |
# |background    |3         |968 |
# |sleeve        |3         |969 |
# |postage       |3         |970 |
# |nya           |3         |971 |
# |哈哈哈哈      |3         |972 |
# |sunday        |3         |973 |
# |keras         |3         |974 |
# |skrg          |3         |975 |
# |kemek         |3         |976 |
# |饰            |2         |977 |
# |赢取          |2         |978 |
# |中等          |2         |979 |
# |发达          |2         |980 |
# |面有          |2         |981 |
# |ipad          |2         |982 |
# |今日          |2         |983 |
# |东马          |2         |984 |
# |丸            |2         |985 |
# |飞            |2         |986 |
# |口味          |2         |987 |
# |弹力          |2         |988 |
# |说话          |2         |989 |
# |ade           |2         |990 |
# |可可          |2         |991 |
# |子            |2         |992 |
# |下            |2         |993 |
# |normal        |2         |994 |
# |马上          |2         |995 |
# |居然          |2         |996 |
# |feel          |2         |997 |
# |选委会        |2         |998 |
# |拒绝          |2         |999 |
# |参考          |2         |1000|
# +--------------+----------+----+
# only showing top 1000 rows
# enter keyword :  seller
# Again? (y / n) :   y
# enter keyword :  好
# Again? (y / n) :   n
# your selected keys is ['seller', '好']
# ==========FILTER SENTENCE BY KEYS==========
# ==========SENTENCE WITH WORD COUNT==========
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...[nltk_data] Downloading package stopwords to /home/pc/nltk_data...
#
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Using state  server backend.                                      (0 + 19) / 19]
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Using state  server backend.
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Using state  server backend.
# Using state  server backend.
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Using state  server backend.
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.047 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.053 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.091 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.133 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.119 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.139 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.130 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.137 seconds.
# Loading model cost 1.096 seconds.
# Prefix dict has been built successfully.
# Prefix dict has been built successfully.
# Loading model cost 1.143 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.144 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.144 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.120 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.131 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.132 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.084 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.109 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.128 seconds.
# Loading model cost 1.140 seconds.
# Prefix dict has been built successfully.
# Prefix dict has been built successfully.
# Deleted hdfs://10.123.51.78:8020/user/social_media/sentence_with_keys
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.578 seconds.                                   (0 + 1) / 1]
# Prefix dict has been built successfully.
# the file is splitted into 1 files to ease the prcessing
# 22/10/11 08:31:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:31:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:31:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:31:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/11 08:31:11 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 2022-10-11 08:31:12.497160: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya_boilerplate/frozen_graph.py:35: UserWarning: Cannot import beam_search_ops from Tensorflow Addons, ['malaya.jawi_rumi.deep_model', 'malaya.phoneme.deep_model', 'malaya.rumi_jawi.deep_model', 'malaya.stem.deep_model'] will not available to use, make sure Tensorflow Addons version >= 0.12.0
#   warnings.warn(
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya_boilerplate/frozen_graph.py:38: UserWarning: check compatible Tensorflow version with Tensorflow Addons at https://github.com/tensorflow/addons/releases
#   warnings.warn(
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya/tokenizer.py:208: FutureWarning: Possible nested set at position 3372
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya/tokenizer.py:208: FutureWarning: Possible nested set at position 3890
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))
# 2022-10-11 08:31:18.676318: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-11 08:31:19.597988: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Deleted /user/social_media/IN
# Deleted /user/social_media/OUT
# ==========FRAME WITH TAG AND TOKEN==========
# Using state  server backend.
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Using state  server backend.
# Using state  server backend.
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Using state  server backend.
# Loading model cost 0.640 seconds.====>                           (10 + 10) / 20]
# Prefix dict has been built successfully.
# Loading model cost 0.694 seconds.=======>                         (11 + 9) / 20]
# Prefix dict has been built successfully.
# Loading model cost 0.760 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.713 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.730 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.725 seconds.
# Prefix dict has been built successfully.
# Deleted /user/social_media/Merge
# removed merge and saved token And Tag
# ==========TOKENS WITH LANGUAGES ASSOCIATED==========
# ==========DATAFRAME WITH LANG, TOKEN AND TAG==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/tokenAndTag
# removed token and tag saved token, tag, and lang
# ==========CREATED BIGRAM==========
# save bigram
# ==========CREATED TRIGRAM==========
# save trigram
# ==========CREATED 4-GRAM==========
# save n4 gram
# ==========CREATED 5-GRAM==========
# save n5 gram
# ==========ASSEMBLE ALL NGRAM==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/N2_GRAM
# Deleted hdfs://10.123.51.78:8020/user/social_media/N3_GRAM
# Deleted hdfs://10.123.51.78:8020/user/social_media/N4_GRAM
# Deleted hdfs://10.123.51.78:8020/user/social_media/N5_GRAM
# remove single gram and save merge gram
# ==========GET NGRAM WITH KEYWORDS ONLY==========
# ==========MARK THE NGRAM WITH KEYWORDS MIDDLE ON IT==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/KeyOnlyData
# remove keyword only and save with center flag
# ==========DF WITH LANG GRAM FREQUENCY==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/langFreq
# ==========DF WITH TOKEN FREQUENCY==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/tokenFreq
# Deleted hdfs://10.123.51.78:8020/user/social_media/MergelangFreq
# ==========DF WITH TAG GRAM FREQUENCY==========
# Deleted hdfs://10.123.51.78:8020/user/social_media/WithTagGramFreq
# Deleted hdfs://10.123.51.78:8020/user/social_media/MergeTokenFreq
# if disk block error happen, need increase the repartition value
# ==========GETTING GRAM TABLE==========
# ==========GETTING SOURCE TABLE==========
