# %%
if __name__ == "__main__":
    ## arguments
    pyspark_bin_path = "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3"
    python_path = "/home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/bin/python39"
    app_name = "social media"
    data_path = "/home/pc/data/parsed_data/1parsed-extract-enwiki.txt"
    hdfs_working_path = "hdfs://10.123.51.78:8020/user/wikipedia/"
    malay_stopword_path = "stopwords-ms.json"
    jieba_replace_csv = "replacement.csv"
    hdfsHost = "hdfs://10.123.51.78"
    hdfsPort = "8020"
    hdfs_working_path_file = "/user/wikipedia/"
    hiveWarehouseDirectory = "hdfs://10.123.51.78:8020/user/hive/warehouse"
    hiveTriftServerAddress = "thrift://g2.bigtop.it:9083"


    # %load_ext autoreload
    # %autoreload 2
    import shutil
    import os
    import json
    import findspark
    findspark.init(pyspark_bin_path)
    from FileIO import *
    import utilities as u
    import pyspark
    from Preprocessing import *
    from pyspark.sql import SparkSession
    from DetectLanguage import *
    from LangAgg import *
    from WordCount import *
    from pyspark.sql.window import Window
    from nltk.corpus import stopwords
    from FilterOutliers import *
    from postagChinese import *
    from JiebaTagToStandardTag import *
    from SegmentDataframe import *
    from PosTagBMBI import *
    from Alternator import *
    from TokenLanguageReplaceTool import *
    from pyspark.ml.feature import NGram
    from KeyGram import *
    from MiddleKey import *
    from StopwordsFilteringTool import *
    import matplotlib.pyplot as plt
    import math


    ################################################################################################################
    ## initialize spark session
    os.environ["HADOOP_USER_NAME"] = "hdfs"
    os.environ["PYSPARK_PYTHON"] = python_path
    os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.12:3.3.0,com.johnsnowlabs.nlp:spark-nlp_2.12:4.2.0 pyspark-shell'


    spark = SparkSession.builder \
        .appName("Spark NLP")\
        .master("local[*]")\
        .config("spark.driver.memory", "70g")\
        .config("spark.sql.warehouse.dir", hiveWarehouseDirectory) \
        .config("spark.sql.catalogImplementation", "hive")\
        .config("hive.metastore.uris", hiveTriftServerAddress) \
        .getOrCreate()

    from PosTagSparkNLP import *


    ################################################################################################################
    ## convert data into avro format
    bi = spark.read.text(data_path).sample(0.001)
    print("================ CONVERTING DATA TO AVRO FORMAT ================")
    write_avro(bi, f"{hdfs_working_path}oriDataBI")
    ################################################################################################################
    ## preprocess data that will affect sentence tokenization
    df = read_avro(spark, f"{hdfs_working_path}oriDataBI")
    pp = pp(df)

    print("================ SAVE THE PREPROCESSED DATA ================")
    write_avro(pp, f"{hdfs_working_path}ppDataBI")
    remove_from_hdfs(f"{hdfs_working_path}oriDataBI")
    ################################################################################################################
    ## doing sentence tokenization on the dataset
    df = read_avro(spark, f"{hdfs_working_path}ppDataBI")
    engSent = get_eng_senDF(df)
    engSent= engSent.withColumn("text", explode(engSent.columns[0])).select("text")

    print("================ SAVE THE SENTENCE TOKENIZE DATA ================")
    write_avro(engSent, hdfs_working_path+"sent_tokenize_bi.avro")
    remove_from_hdfs(f"{hdfs_working_path}ppDataBI")
    ################################################################################################################
    ## preprocessing II
    df = read_avro(spark, f"{hdfs_working_path}sent_tokenize_bi.avro")
    p2 = preprocessing2(df, "text")

    print("================ SAVE THE CLEANED SENTENCE DATA ================")
    write_avro(p2, hdfs_working_path+"p2_bi")
    remove_from_hdfs(f"{hdfs_working_path}sent_tokenize_bi.avro")
    ################################################################################################################
    ## preprocessing III
    df = read_avro(spark, f"{hdfs_working_path}p2_bi")
    sen = get_sentence(df, "text").select("text")
    flat = sen.select(flatten(sen.text).alias('text'))
    a = flat.rdd.map(lambda x : (' '.join(x[0]),1)).toDF(["text", "id"]).drop("id")

    print("================ SAVE THE FINAL PROCESS SENTENCE DATA ================")
    write_avro(a, f"{hdfs_working_path}final_process_bi")
    remove_from_hdfs(f"{hdfs_working_path}p2_bi")
    ################################################################################################################
    ## Word count statistics
    malayStopWords = set(json.load(open(malay_stopword_path)))
    stopwordsSet = set(stopwords.words('english') + stopwords.words('chinese') ).union(malayStopWords)

    df = read_avro(spark, f"{hdfs_working_path}final_process_bi")

    stopWordsRemoval = StopwordsFilteringTool(stopwordsSet)

    nsbi = stopWordsRemoval.get_no_stop_word_df(df, "text")

    wc = \
        nsbi.rdd.flatMap(lambda x : x.text) \
        .map(lambda x : (x,1)).reduceByKey(lambda V1, V2 : V1+V2) \
        .toDF(["word","word_count"])

    wc\
        .select("word","word_count", F.row_number() \
                .over(Window.partitionBy().orderBy(desc(wc['word_count']))) \
                .alias("id")).show(1000)
    ################################################################################################################
    ## Prompt user to enter the keywords
    ## Select topics
    keys = []
    want_choose = True
    while want_choose:
        key = input("enter keyword : ")
        keys.append(key)
        decision = input("Again? (y / n) :  ")
        if not (decision.upper() == 'Y' or decision.upper() == 'YES'):
            want_choose = False
    print("your selected keys is " + str(keys))
    ################################################################################################################
    regex = "|".join(keys)
    filtered = df.filter( df.text.rlike(regex))

    print("================ SAVE THE FILTERED DATA ================")
    write_avro(filtered, f"{hdfs_working_path}filtered_bi_data")
    ################################################################################################################
    ## create sentence word count statistics
    df = read_avro(spark, f"{hdfs_working_path}filtered_bi_data")
    with_statistics = df.withColumn("token", u.tokenize_chineseDF(df.text))
    with_statistics = with_statistics.withColumn("length", size(with_statistics.token))
    df = with_statistics.select("text", "length")

    print("==========SENTENCE WITH WORD COUNT==========")
    write_avro(df, hdfs_working_path+"bi_sentence_with_statistics")
    remove_from_hdfs(hdfs_working_path+"filtered_bi_data")
    ################################################################################################################
    ## remove the outliers
    s = read_avro(spark, hdfs_working_path+"bi_sentence_with_statistics")
    s = s.coalesce(74)
    sC = s.select(s.length)
    sC.toPandas().plot.box()
    plt.show()
    s_detect = find_outliers(s)
    noS = s_detect.filter((s_detect.total_outliers < 1)  & (s_detect.length > 3))
    sC = noS.select(noS.length)
    sC.toPandas().plot.box()
    plt.show()

    print("==========SENTENCE WITHOUT OUTLIERS==========")
    write_avro(noS, hdfs_working_path+"sentence_without_out")
    remove_from_hdfs(hdfs_working_path+"bi_sentence_with_statistics")
    ################################################################################################################
    ## pos tag
    df = read_avro(spark, hdfs_working_path+"sentence_without_out")
    df = df.withColumnRenamed("text", "sentence")
    result = pipeline.fit(df).transform(df)
    final = result.selectExpr("token.result as token","pos.result as pos")

    print("==========BI SENTENCES WITH TAGGING==========")
    write_avro(final, hdfs_working_path+"bi_sentence_with_tagging")
    ################################################################################################################
    ## create n-gram
    a = read_avro(spark, hdfs_working_path+"bi_sentence_with_tagging")
    a = a.repartition(60)
    a= a.withColumn("sentence_id", F.monotonically_increasing_id())
    a = a.rdd.map(lambda x : (x.sentence_id," ".join(x.token), x.token, x.pos)).toDF(["sentence_id", "original","token","tag"])
    write_avro(a, hdfs_working_path+"bi_sentence_with_tagging_format")
    remove_from_hdfs(hdfs_working_path+"bi_sentence_with_tagging")
    ################################################################################################################
    a = read_avro(spark, hdfs_working_path+"bi_sentence_with_tagging_format")
    ################################################################################################################
    ## bigram
    tokenNgram =NGram(n=2, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=2, inputCol="tag", outputCol="tag_gram")
    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)
    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))

    print("==========CREATED BIGRAM==========")
    write_avro(t, hdfs_working_path+"BI_N2_GRAM")
    ################################################################################################################
    ## trigram
    tokenNgram =NGram(n=3, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=3, inputCol="tag", outputCol="tag_gram")

    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)

    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


    print("==========CREATED TRIGRAM==========")
    write_avro(t, hdfs_working_path+"BI_N3_GRAM")
    ################################################################################################################
    ## n4 gram
    tokenNgram =NGram(n=4, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=4, inputCol="tag", outputCol="tag_gram")

    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)

    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


    print("==========CREATED N4 GRAM==========")
    write_avro(t, hdfs_working_path+"BI_N4_GRAM")
    ################################################################################################################
    ## n5 gram
    tokenNgram =NGram(n=5, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=5, inputCol="tag", outputCol="tag_gram")

    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)

    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


    print("==========CREATED N5 GRAM==========")
    write_avro(t, hdfs_working_path+"BI_N5_GRAM")
    ################################################################################################################
    ## merge ngram
    n2 = read_avro(spark, hdfs_working_path+"BI_N2_GRAM")
    n3 = read_avro(spark, hdfs_working_path+"BI_N3_GRAM")
    n4 = read_avro(spark, hdfs_working_path+"BI_N4_GRAM")
    n5 = read_avro(spark, hdfs_working_path+"BI_N5_GRAM")


    n2 = n2.withColumn("gram_type", lit(2))
    n3 = n3.withColumn("gram_type", lit(3))
    n4 = n4.withColumn("gram_type", lit(4))
    n5 = n5.withColumn("gram_type", lit(5))


    merge = unionAll(n2, n3, n4, n5)

    print("==========MERGED THE NGRAMS==========")
    write_avro(merge, hdfs_working_path+"BI_MERGE_GRAM")
    ################################################################################################################
    ## gram frequency statistics
    ## Tag frequency
    ################################################################################################################
    ## filter n gram with key words
    df = read_avro(spark, hdfs_working_path+"BI_MERGE_GRAM")
    keys = set(keys)
    keyGramFilter = KeyGram(keys)
    withKeyOnly = keyGramFilter.getDFwithKeywordsOnly(df)

    print("==========GET NGRAM WITH KEYWORDS ONLY==========")
    write_avro(withKeyOnly, f"{hdfs_working_path}BI_KeyOnlyData")
    ################################################################################################################
    # create the column to identify whether keyword at middle
    df = read_avro(spark,  f"{hdfs_working_path}BI_KeyOnlyData")
    mid = MiddleKey(keys)
    withMiddleFlag = df.withColumn("middle_key", mid.middleUDF(df.gram_type, df.token_gram))

    print("==========MARK THE NGRAM WITH KEYWORDS MIDDLE ON IT==========")
    write_avro(withMiddleFlag, f"{hdfs_working_path}BI_MiddleFlagData")
    remove_from_hdfs(f"{hdfs_working_path}BI_KeyOnlyData")
    ################################################################################################################
    ## Frequency statistics
    ## tag frequency
    df = read_avro(spark,  f"{hdfs_working_path}BI_MiddleFlagData")
    tagFreq = df.groupBy("tag_gram").count().withColumnRenamed("count", "tag_gram_f")
    write_avro(tagFreq, hdfs_working_path+"BI_TAG_FREQ")
    tagFreq = read_avro(spark, hdfs_working_path+"BI_TAG_FREQ")
    withtagFBI = df.join(tagFreq, df.tag_gram == tagFreq.tag_gram).drop(tagFreq.tag_gram)

    print("==========COMPUTED THE TAG FREQUENCY==========")
    write_avro(withtagFBI, hdfs_working_path+"BI_TAG_F")
    remove_from_hdfs(hdfs_working_path+"BI_TAG_FREQ")
    ################################################################################################################
    ## Token frequency
    df = read_avro(spark, hdfs_working_path+"BI_TAG_F")
    bitokenFreq = df.groupBy("token_gram").count().withColumnRenamed("count", "token_gram_f")
    write_avro(bitokenFreq, hdfs_working_path+"BI_TOKEN_FREQ")
    tokenFreq = read_avro(spark, hdfs_working_path+"BI_TOKEN_FREQ")
    biwithTokF = df.join(tokenFreq, df.token_gram == tokenFreq.token_gram).drop(tokenFreq.token_gram)

    print("==========COMPUTED THE TOKEN FREQUENCY==========")
    write_avro(biwithTokF, hdfs_working_path+"BI_TOKEN_F")
    remove_from_hdfs(hdfs_working_path+"BI_TOKEN_FREQ")
    remove_from_hdfs(hdfs_working_path+"BI_TAG_F")
    ################################################################################################################
    ## Table Normalization
    ## Gram table
    df = read_avro(spark, hdfs_working_path+"BI_TOKEN_F")
    gram_table = df.select("sentence_id", "pos", "token_gram", "token_gram_f", "tag_gram", "tag_gram_f", "gram_type", "containsKey", "middle_key")
    gram_table = gram_table.withColumn("uniqueID", monotonically_increasing_id())
    write_avro(gram_table, hdfs_working_path+"BI_GRAM_TABLE")
    ################################################################################################################
    ## Source Table
    originalSentence  = df.dropDuplicates((['sentence_id'])).select("sentence_id", "original", "tag", "token")
    originalSentence = originalSentence.repartition(800)
    print("if disk block error happen, try increase the value of repartition")
    originalSentence = originalSentence.withColumn("uniqueID", monotonically_increasing_id())
    write_avro(originalSentence, hdfs_working_path+"BI_SOURCE_TABLE")
    ################################################################################################################
    ## Into Hive
    gram_table = read_avro(spark, hdfs_working_path+"BI_GRAM_TABLE")
    original_table = read_avro(spark, hdfs_working_path+"BI_SOURCE_TABLE")

    spark.sql("create database if not exists wikipedia_db;")
    spark.sql("use wikipedia_db;")
    spark.sql("drop table if exists gram_table_en;")
    spark.sql("drop table if exists source_data_en;")


    gram_table.write\
    .format("orc") \
    .mode("overwrite") \
    .saveAsTable("wikipedia_db.gram_table_en")


    original_table.write\
    .format("orc") \
    .mode("overwrite") \
    .saveAsTable("wikipedia_db.source_data_en")

    ################################################################################################################
    ## Analytics
    # analytics : Top 10 Common Pos Pattern
    Q="""
    select
        distinct tag_gram,
        tag_gram_f
    from
        gram_table_en
    order by
        tag_gram_f DESC limit 10;
    """

    SMPos = spark.sql(Q).toPandas()

    fig, ax = plt.subplots(1,1,figsize=(15,5))

    x = SMPos['tag_gram'][:10].tolist()
    y = SMPos['tag_gram_f'][:10].tolist()
    ax.barh(x,y)
    ax.set_title('Top 10 Most Common POS Patterns in Wikipedia English')
    for index, value in enumerate(y):
        ax.text(value, index,
                 str(value))
    ax.invert_yaxis()

    import shutil
    try:
        shutil.rmtree("visualization")
    except:
        pass
    
    plt.savefig('visualization/top10POSPattern', dpi=300, bbox_inches='tight')
    ################################################################################################################
    ## Analytics
    # analytics : Top 10 Common Token Pattern
    Q="""
    select
        distinct token_gram,
        token_gram_f
    from
        gram_table_en
    order by
        token_gram_f DESC limit 10;
    """

    SMtok = spark.sql(Q).toPandas()

    fig, ax = plt.subplots(1,1,figsize=(15,5))

    x = SMtok['token_gram'][:10].tolist()
    y = SMtok['token_gram_f'][:10].tolist()
    ax.barh(x,y)
    ax.set_title('Top 10 Most Common Token Patterns in Wikipedia English')
    for index, value in enumerate(y):
        ax.text(value, index,
                 str(value))
    ax.invert_yaxis()

    plt.savefig('visualization/top10TokenPattern', dpi=300, bbox_inches='tight')
# Out:
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Using state  server backend.
# 2022-10-10 10:58:13.950451: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/lib/python3.9/site-packages/malaya_boilerplate/frozen_graph.py:35: UserWarning: Cannot import beam_search_ops from Tensorflow Addons, ['malaya.jawi_rumi.deep_model', 'malaya.phoneme.deep_model', 'malaya.rumi_jawi.deep_model', 'malaya.stem.deep_model'] will not available to use, make sure Tensorflow Addons version >= 0.12.0
#   warnings.warn(
# Warning: Ignoring non-Spark config property: hive.metastore.uris
# :: loading settings :: url = jar:file:/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/pc/.ivy2/cache
# The jars for the packages stored in: /home/pc/.ivy2/jars
# org.apache.spark#spark-avro_2.12 added as a dependency
# com.johnsnowlabs.nlp#spark-nlp_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-4d2ab5fc-cd4f-4274-8c6d-f7e8cf32a1c2;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-avro_2.12;3.3.0 in central
# 	found org.tukaani#xz;1.8 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found com.johnsnowlabs.nlp#spark-nlp_2.12;4.2.0 in central
# 	found com.typesafe#config;1.4.2 in central
# 	found org.rocksdb#rocksdbjni;6.29.5 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.828 in central
# 	found com.github.universal-automata#liblevenshtein;3.0.0 in central
# 	found com.google.code.findbugs#annotations;3.0.1 in central
# 	found net.jcip#jcip-annotations;1.0 in central
# 	found com.google.code.findbugs#jsr305;3.0.1 in central
# 	found com.google.protobuf#protobuf-java-util;3.0.0-beta-3 in central
# 	found com.google.protobuf#protobuf-java;3.0.0-beta-3 in central
# 	found com.google.code.gson#gson;2.3 in central
# 	found it.unimi.dsi#fastutil;7.0.12 in central
# 	found org.projectlombok#lombok;1.16.8 in central
# 	found org.slf4j#slf4j-api;1.7.21 in central
# 	found com.navigamez#greex;1.0 in central
# 	found dk.brics.automaton#automaton;1.11-8 in central
# 	found com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.4.3 in central
# :: resolution report :: resolve 387ms :: artifacts dl 27ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.11.828 from central in [default]
# 	com.github.universal-automata#liblevenshtein;3.0.0 from central in [default]
# 	com.google.code.findbugs#annotations;3.0.1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.1 from central in [default]
# 	com.google.code.gson#gson;2.3 from central in [default]
# 	com.google.protobuf#protobuf-java;3.0.0-beta-3 from central in [default]
# 	com.google.protobuf#protobuf-java-util;3.0.0-beta-3 from central in [default]
# 	com.johnsnowlabs.nlp#spark-nlp_2.12;4.2.0 from central in [default]
# 	com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.4.3 from central in [default]
# 	com.navigamez#greex;1.0 from central in [default]
# 	com.typesafe#config;1.4.2 from central in [default]
# 	dk.brics.automaton#automaton;1.11-8 from central in [default]
# 	it.unimi.dsi#fastutil;7.0.12 from central in [default]
# 	net.jcip#jcip-annotations;1.0 from central in [default]
# 	org.apache.spark#spark-avro_2.12;3.3.0 from central in [default]
# 	org.projectlombok#lombok;1.16.8 from central in [default]
# 	org.rocksdb#rocksdbjni;6.29.5 from central in [default]
# 	org.slf4j#slf4j-api;1.7.21 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.tukaani#xz;1.8 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   20  |   0   |   0   |   0   ||   20  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-4d2ab5fc-cd4f-4274-8c6d-f7e8cf32a1c2
# 	confs: [default]
# 	0 artifacts copied, 20 already retrieved (0kB/23ms)
# 22/10/10 10:58:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# pos_ud_ewt download started this may take some time.
# Approximate size to download 2.2 MB
# [ | ]pos_ud_ewt download started this may take some time.
# Approximate size to download 2.2 MB
# [ / ]Download done! Loading the resource.
# [OK!]
# ================ CONVERTING DATA TO AVRO FORMAT ================
# ================ SAVE THE PREPROCESSED DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/oriDataBI
# ================ SAVE THE SENTENCE TOKENIZE DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/ppDataBI
# ================ SAVE THE CLEANED SENTENCE DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/sent_tokenize_bi.avro
# ================ SAVE THE FINAL PROCESS SENTENCE DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/p2_bi
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.593 seconds.                                 (0 + 15) / 15]
# Prefix dict has been built successfully.
# Loading model cost 0.594 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.597 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.596 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.598 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.603 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.602 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.606 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.613 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.599 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.648 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.639 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.647 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.640 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.659 seconds.
# Prefix dict has been built successfully.
# 22/10/10 10:59:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/10 10:59:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/10 10:59:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +--------------+----------+----+
# |          word|word_count|  id|
# +--------------+----------+----+
# |          also|      1007|   1|
# |         first|       888|   2|
# |           new|       863|   3|
# |           one|       842|   4|
# |           two|       675|   5|
# |          time|       549|   6|
# |      american|       541|   7|
# |             p|       530|   8|
# |         would|       519|   9|
# |          used|       489|  10|
# |         years|       479|  11|
# |           may|       455|  12|
# |            th|       440|  13|
# |          john|       428|  14|
# |          many|       423|  15|
# |        united|       410|  16|
# |    university|       405|  17|
# |             b|       397|  18|
# |          made|       389|  19|
# |           age|       386|  20|
# |         later|       380|  21|
# |        states|       375|  22|
# |          part|       356|  23|
# |        people|       351|  24|
# |          city|       351|  25|
# |         world|       350|  26|
# |        school|       348|  27|
# |     including|       340|  28|
# |         known|       328|  29|
# |         three|       321|  30|
# |        series|       312|  31|
# |          year|       311|  32|
# |           war|       311|  33|
# |    population|       310|  34|
# |        became|       297|  35|
# |         house|       293|  36|
# |        family|       292|  37|
# |       however|       291|  38|
# |        called|       291|  39|
# |      national|       291|  40|
# |         state|       289|  41|
# |             n|       287|  42|
# |          well|       287|  43|
# |         early|       284|  44|
# |         music|       283|  45|
# |          high|       280|  46|
# |         south|       278|  47|
# |        second|       269|  48|
# |          film|       269|  49|
# |         north|       267|  50|
# |          town|       262|  51|
# |            us|       256|  52|
# |          name|       255|  53|
# |     following|       252|  54|
# |         times|       247|  55|
# |       company|       245|  56|
# |       british|       245|  57|
# |           use|       244|  58|
# |       english|       243|  59|
# |         james|       243|  60|
# |          june|       241|  61|
# |       several|       241|  62|
# |         since|       239|  63|
# |          area|       236|  64|
# |         press|       236|  65|
# |       century|       235|  66|
# |         group|       230|  67|
# |             c|       230|  68|
# |          work|       230|  69|
# |             r|       229|  70|
# |         found|       228|  71|
# |          life|       226|  72|
# |            st|       225|  73|
# |            op|       224|  74|
# |       britten|       223|  75|
# |             é|       220|  76|
# |          home|       219|  77|
# |           end|       216|  78|
# |          july|       216|  79|
# |          york|       215|  80|
# |          yous|       214|  81|
# |        number|       212|  82|
# |    government|       211|  83|
# |        county|       211|  84|
# |      released|       210|  85|
# |         march|       209|  86|
# |            de|       209|  87|
# |      december|       207|  88|
# |          four|       205|  89|
# |      children|       204|  90|
# |           due|       203|  91|
# |         party|       203|  92|
# |         death|       201|  93|
# |         radon|       200|  94|
# |        living|       197|  95|
# |       another|       196|  96|
# |            pp|       193|  97|
# |           day|       192|  98|
# |         place|       191|  99|
# |          west|       191| 100|
# |         right|       189| 101|
# |       college|       188| 102|
# |       history|       187| 103|
# |         river|       187| 104|
# |        august|       186| 105|
# |         white|       186| 106|
# |       general|       185| 107|
# |          like|       185| 108|
# |      although|       185| 109|
# |          army|       185| 110|
# |         along|       185| 111|
# |          game|       185| 112|
# |         women|       184| 113|
# |        public|       183| 114|
# |         often|       180| 115|
# |         among|       180| 116|
# |         began|       179| 117|
# |          left|       179| 118|
# |        island|       178| 119|
# |        league|       177| 120|
# |     published|       177| 121|
# |         could|       177| 122|
# |         black|       176| 123|
# |          died|       176| 124|
# |             á|       176| 125|
# |          born|       176| 126|
# |       october|       174| 127|
# |      february|       174| 128|
# |         major|       172| 129|
# |        system|       172| 130|
# |     according|       171| 131|
# |         great|       170| 132|
# |        church|       170| 133|
# |          much|       170| 134|
# |          show|       169| 135|
# |        former|       168| 136|
# |        burton|       167| 137|
# |       january|       167| 138|
# |       average|       167| 139|
# |          band|       166| 140|
# |      november|       165| 141|
# |      language|       165| 142|
# |          king|       165| 143|
# |          last|       162| 144|
# |         small|       162| 145|
# |            ii|       162| 146|
# |        around|       160| 147|
# |          east|       160| 148|
# |          park|       159| 149|
# |          book|       158| 150|
# |          said|       158| 151|
# |          best|       157| 152|
# |        median|       156| 153|
# |         third|       156| 154|
# |           set|       156| 155|
# |             j|       154| 156|
# |         still|       154| 157|
# |          form|       154| 158|
# |       william|       152| 159|
# |         total|       152| 160|
# |        london|       152| 161|
# |         games|       151| 162|
# |         union|       151| 163|
# |          even|       151| 164|
# |          back|       150| 165|
# |          land|       150| 166|
# |         works|       149| 167|
# |      original|       149| 168|
# |          took|       147| 169|
# |         royal|       147| 170|
# |       located|       146| 171|
# |        played|       146| 172|
# |       version|       146| 173|
# |        income|       146| 174|
# |        palace|       146| 175|
# |        census|       146| 176|
# |       present|       146| 177|
# |         every|       145| 178|
# |          line|       145| 179|
# |          near|       145| 180|
# |           per|       144| 181|
# |             v|       144| 182|
# |            km|       144| 183|
# |         deere|       144| 184|
# |         large|       142| 185|
# | international|       142| 186|
# |        season|       141| 187|
# |          role|       140| 188|
# |         named|       140| 189|
# |         local|       140| 190|
# |       species|       139| 191|
# |        player|       139| 192|
# |         built|       139| 193|
# |        single|       139| 194|
# |          race|       138| 195|
# |     president|       138| 196|
# |       various|       138| 197|
# |             e|       138| 198|
# |      cummings|       137| 199|
# |          long|       137| 200|
# |         based|       137| 201|
# |       written|       136| 202|
# |       include|       136| 203|
# |        common|       136| 204|
# |           man|       135| 205|
# |       married|       135| 206|
# |        polish|       135| 207|
# |     different|       134| 208|
# |       members|       133| 209|
# |          late|       133| 210|
# |         power|       132| 211|
# |      together|       132| 212|
# |      included|       132| 213|
# |           old|       130| 214|
# |          five|       129| 215|
# |        within|       129| 216|
# |          main|       129| 217|
# |      building|       129| 218|
# |        modern|       128| 219|
# |       example|       128| 220|
# |         force|       128| 221|
# |     humphries|       127| 222|
# |        robert|       127| 223|
# |          veil|       127| 224|
# |        social|       127| 225|
# |           son|       126| 226|
# |         album|       126| 227|
# |      received|       126| 228|
# |        apache|       126| 229|
# |         given|       126| 230|
# |        center|       126| 231|
# |    considered|       126| 232|
# |       council|       125| 233|
# |          held|       124| 234|
# |        member|       124| 235|
# |          make|       124| 236|
# |    households|       124| 237|
# |          side|       123| 238|
# |          page|       123| 239|
# |         space|       123| 240|
# |        panama|       123| 241|
# |          palm|       122| 242|
# |        square|       122| 243|
# |          came|       122| 244|
# |        weaver|       122| 245|
# |        french|       122| 246|
# |          blue|       121| 247|
# |   development|       121| 248|
# |          size|       121| 249|
# |          team|       120| 250|
# |       england|       120| 251|
# |         young|       120| 252|
# |        region|       120| 253|
# |     community|       119| 254|
# |       service|       119| 255|
# |           sir|       119| 256|
# |           men|       119| 257|
# |           act|       119| 258|
# |          body|       118| 259|
# |          next|       118| 260|
# |             ü|       118| 261|
# |             ā|       118| 262|
# |         nepal|       117| 263|
# |         class|       117| 264|
# |         using|       117| 265|
# |           led|       117| 266|
# |         order|       117| 267|
# |        street|       117| 268|
# |             l|       116| 269|
# |         point|       115| 270|
# |        served|       115| 271|
# |    production|       115| 272|
# |         seven|       115| 273|
# |       usually|       115| 274|
# |        others|       115| 275|
# |       similar|       114| 276|
# |   determinant|       114| 277|
# |   established|       114| 278|
# |       society|       114| 279|
# |        period|       113| 280|
# |          take|       113| 281|
# |         books|       113| 282|
# |      military|       112| 283|
# |           way|       112| 284|
# |          head|       112| 285|
# |         males|       112| 286|
# |           law|       112| 287|
# |        though|       112| 288|
# |          list|       112| 289|
# |       central|       111| 290|
# |             f|       111| 291|
# |         award|       111| 292|
# |       country|       111| 293|
# |       america|       111| 294|
# |           see|       110| 295|
# |      official|       110| 296|
# |      district|       110| 297|
# |          road|       109| 298|
# |          days|       109| 299|
# |      aircraft|       109| 300|
# |             k|       108| 301|
# |        german|       108| 302|
# |       females|       108| 303|
# |         never|       108| 304|
# |          song|       108| 305|
# |             ı|       108| 306|
# |      european|       107| 307|
# |           run|       107| 308|
# |         child|       107| 309|
# |      southern|       107| 310|
# |          went|       107| 311|
# |       science|       107| 312|
# |     political|       106| 313|
# |       village|       106| 314|
# |      families|       106| 315|
# |         story|       106| 316|
# |       support|       106| 317|
# |        become|       106| 318|
# |         short|       106| 319|
# |          less|       105| 320|
# |           vol|       105| 321|
# |          case|       105| 322|
# |             g|       105| 323|
# |        career|       105| 324|
# |       control|       104| 325|
# |      township|       104| 326|
# |        george|       104| 327|
# |       without|       103| 328|
# |         films|       103| 329|
# |      grinnell|       103| 330|
# |         moved|       102| 331|
# |         older|       102| 332|
# |        female|       102| 333|
# |         radio|       102| 334|
# |     continued|       102| 335|
# |       highway|       102| 336|
# |         henry|       102| 337|
# |     performed|       102| 338|
# |             h|       101| 339|
# |        almost|       101| 340|
# |         peter|       101| 341|
# |        office|       101| 342|
# |        father|       101| 343|
# |      election|       101| 344|
# |      returned|       101| 345|
# |        scream|       100| 346|
# |      brittens|       100| 347|
# |    australian|       100| 348|
# |         title|        99| 349|
# |      business|        98| 350|
# |        native|        98| 351|
# |         opera|        98| 352|
# |          gold|        98| 353|
# |           iii|        98| 354|
# |          lead|        98| 355|
# |           low|        98| 356|
# |          seen|        97| 357|
# |         court|        97| 358|
# |          free|        97| 359|
# |       studies|        97| 360|
# |        middle|        97| 361|
# |       charles|        97| 362|
# |        valley|        97| 363|
# |       million|        97| 364|
# |       density|        96| 365|
# |     retrieved|        96| 366|
# |     important|        96| 367|
# |         words|        96| 368|
# |          wife|        95| 369|
# |         woman|        95| 370|
# |      standard|        95| 371|
# |       created|        95| 372|
# |        sultan|        95| 373|
# |        either|        95| 374|
# |        opened|        94| 375|
# |         final|        94| 376|
# |         actor|        94| 377|
# |        kaurna|        94| 378|
# |         areas|        94| 379|
# |     character|        94| 380|
# |          hall|        94| 381|
# |         songs|        94| 382|
# |           six|        94| 383|
# |          love|        93| 384|
# |           top|        93| 385|
# |       section|        93| 386|
# |   krasnoyarsk|        93| 387|
# |            ed|        92| 388|
# |        mother|        92| 389|
# |        forces|        92| 390|
# |         study|        92| 391|
# |         piano|        92| 392|
# |       special|        91| 393|
# |       project|        91| 394|
# |           red|        91| 395|
# |      northern|        91| 396|
# |             w|        91| 397|
# |          bill|        91| 398|
# |    television|        91| 399|
# |          lost|        91| 400|
# |     generally|        91| 401|
# |      students|        90| 402|
# |            iv|        90| 403|
# |        harper|        90| 404|
# |         stage|        90| 405|
# |     developed|        90| 406|
# |        garden|        90| 407|
# |       kingdom|        89| 408|
# |        making|        89| 409|
# |       popular|        89| 410|
# |        little|        89| 411|
# |         route|        89| 412|
# |       records|        89| 413|
# |         novel|        89| 414|
# |        signed|        88| 415|
# |        flight|        88| 416|
# |        rather|        88| 417|
# |          play|        88| 418|
# |        battle|        88| 419|
# |      addition|        88| 420|
# |       founded|        88| 421|
# |         water|        87| 422|
# |         units|        87| 423|
# |      minister|        87| 424|
# |         races|        87| 425|
# |            uk|        86| 426|
# |        record|        86| 427|
# |      movement|        86| 428|
# |    collection|        86| 429|
# |       library|        86| 430|
# |         karen|        86| 431|
# |         wrote|        86| 432|
# |             í|        85| 433|
# |      position|        85| 434|
# |         taken|        85| 435|
# |   individuals|        85| 436|
# |         chief|        85| 437|
# |        attack|        85| 438|
# |       schools|        84| 439|
# |       richard|        84| 440|
# |      produced|        84| 441|
# |          open|        84| 442|
# |         night|        84| 443|
# |       pacific|        84| 444|
# |    california|        84| 445|
# |         today|        83| 446|
# |       western|        83| 447|
# |     education|        83| 448|
# |     sometimes|        83| 449|
# |       musical|        83| 450|
# |       started|        83| 451|
# |          full|        82| 452|
# |        formed|        82| 453|
# |         range|        82| 454|
# |          fire|        82| 455|
# |    originally|        82| 456|
# |             ó|        81| 457|
# |      economic|        81| 458|
# |         field|        81| 459|
# |        indian|        81| 460|
# |         civil|        81| 461|
# |      research|        81| 462|
# |        france|        81| 463|
# |       release|        81| 464|
# |        schiff|        81| 465|
# |          gave|        81| 466|
# |       brought|        81| 467|
# |      appeared|        81| 468|
# |             x|        80| 469|
# |      recorded|        80| 470|
# |   performance|        80| 471|
# |        health|        80| 472|
# |    throughout|        80| 473|
# |          live|        80| 474|
# |     orchestra|        80| 475|
# |           san|        80| 476|
# |     household|        80| 477|
# |          site|        80| 478|
# |        across|        80| 479|
# |          word|        79| 480|
# |      followed|        79| 481|
# |        engine|        79| 482|
# |      features|        79| 483|
# |         lower|        79| 484|
# |        matrix|        79| 485|
# |    introduced|        79| 486|
# |   traditional|        79| 487|
# |          upon|        79| 488|
# |      imperial|        78| 489|
# |         money|        78| 490|
# |         harem|        78| 491|
# |        worked|        77| 492|
# |    politician|        77| 493|
# |         david|        77| 494|
# |        centre|        77| 495|
# |     equipment|        77| 496|
# |        mexico|        77| 497|
# |       leading|        77| 498|
# |    changeable|        77| 499|
# |          earl|        76| 500|
# |        review|        76| 501|
# |   information|        76| 502|
# |      includes|        76| 503|
# |      daughter|        76| 504|
# |       spanish|        76| 505|
# |     announced|        75| 506|
# |      congress|        75| 507|
# |          lord|        75| 508|
# |   independent|        75| 509|
# |            sr|        75| 510|
# |      possible|        75| 511|
# |            la|        75| 512|
# |      interest|        75| 513|
# |          paul|        74| 514|
# |          soon|        74| 515|
# |       manager|        74| 516|
# |            go|        74| 517|
# |          tree|        74| 518|
# |    department|        74| 519|
# |          iowa|        74| 520|
# |      composer|        74| 521|
# |        author|        74| 522|
# |       chester|        74| 523|
# |       success|        74| 524|
# |        treaty|        74| 525|
# |    democratic|        73| 526|
# |       decided|        73| 527|
# |       instead|        73| 528|
# |     religious|        73| 529|
# |           hit|        73| 530|
# |          good|        73| 531|
# |      columbia|        73| 532|
# |         stars|        73| 533|
# |       african|        73| 534|
# |         level|        73| 535|
# |        groups|        73| 536|
# |          sent|        73| 537|
# |        events|        73| 538|
# |       ancient|        73| 539|
# |          duty|        73| 540|
# |          face|        73| 541|
# |     described|        73| 542|
# |        joined|        72| 543|
# |         sound|        72| 544|
# |        thomas|        72| 545|
# |           los|        72| 546|
# |         trade|        72| 547|
# |         light|        72| 548|
# |         close|        72| 549|
# |       despite|        72| 550|
# |         stamp|        72| 551|
# |      festival|        71| 552|
# |        speech|        71| 553|
# |          thus|        71| 554|
# |           art|        71| 555|
# |        guitar|        71| 556|
# |       edition|        71| 557|
# |            nd|        71| 558|
# |      baseball|        71| 559|
# |            tv|        71| 560|
# |         model|        71| 561|
# |          half|        71| 562|
# |    historical|        70| 563|
# |   significant|        70| 564|
# |   association|        70| 565|
# |         palms|        70| 566|
# |         whose|        70| 567|
# |        future|        70| 568|
# |     courtyard|        70| 569|
# |         kreme|        70| 570|
# |        ground|        70| 571|
# |     operation|        70| 572|
# |        result|        69| 573|
# |    successful|        69| 574|
# |    especially|        69| 575|
# |        edward|        69| 576|
# |        volume|        69| 577|
# |          text|        69| 578|
# |         newar|        69| 579|
# |        krispy|        69| 580|
# |     available|        69| 581|
# |      remained|        69| 582|
# |          fort|        69| 583|
# |           get|        69| 584|
# |         style|        69| 585|
# |          dark|        69| 586|
# |         terms|        69| 587|
# |        higher|        68| 588|
# |          date|        68| 589|
# |      believed|        68| 590|
# |      reported|        68| 591|
# |           big|        68| 592|
# |          base|        68| 593|
# |      division|        67| 594|
# |        larger|        67| 595|
# |             ğ|        67| 596|
# |    characters|        67| 597|
# |      personal|        67| 598|
# |        border|        67| 599|
# |        silver|        67| 600|
# |    eventually|        67| 601|
# |       culture|        67| 602|
# |         grand|        67| 603|
# |        rights|        67| 604|
# |    republican|        67| 605|
# |    literature|        67| 606|
# |       private|        66| 607|
# |          room|        66| 608|
# |        houses|        66| 609|
# |      director|        66| 610|
# |      elements|        66| 611|
# |        design|        66| 612|
# |      involved|        66| 613|
# |          real|        66| 614|
# |      accessed|        66| 615|
# |       husband|        65| 616|
# |         parts|        65| 617|
# |      illinois|        65| 618|
# |        person|        65| 619|
# |          turn|        65| 620|
# |        studio|        65| 621|
# |    technology|        65| 622|
# |          club|        65| 623|
# |       largest|        65| 624|
# |       russian|        65| 625|
# |       woolman|        65| 626|
# |         added|        65| 627|
# |  municipality|        64| 628|
# |      training|        64| 629|
# |     committee|        64| 630|
# |             ö|        64| 631|
# |       michael|        64| 632|
# |    washington|        64| 633|
# |       writing|        64| 634|
# |      replaced|        64| 635|
# |       journal|        64| 636|
# |       meaning|        64| 637|
# |      governor|        64| 638|
# |        stakes|        64| 639|
# |       related|        64| 640|
# |          rule|        64| 641|
# |       britain|        64| 642|
# |        killed|        63| 643|
# |     buildings|        63| 644|
# |         front|        63| 645|
# |         notes|        63| 646|
# |         alone|        63| 647|
# |       opening|        63| 648|
# |          post|        63| 649|
# |       apaches|        63| 650|
# |    additional|        63| 651|
# |      magazine|        63| 652|
# |       process|        63| 653|
# |          hong|        63| 654|
# |        months|        63| 655|
# |       eastern|        63| 656|
# |          mile|        62| 657|
# |        museum|        62| 658|
# |          care|        62| 659|
# |      lowfloor|        62| 660|
# |       elected|        62| 661|
# |          must|        62| 662|
# |         peace|        62| 663|
# |          type|        62| 664|
# |     languages|        62| 665|
# |        summer|        62| 666|
# |          mark|        61| 667|
# |      football|        61| 668|
# |        longer|        61| 669|
# |      designed|        61| 670|
# |        entire|        61| 671|
# |          hand|        61| 672|
# |          news|        61| 673|
# |          able|        61| 674|
# |       federal|        61| 675|
# |     beginning|        61| 676|
# |       chamber|        61| 677|
# |             ō|        61| 678|
# |        europe|        60| 679|
# |     secretary|        60| 680|
# |         queen|        60| 681|
# |     christian|        60| 682|
# |       current|        60| 683|
# |        annual|        60| 684|
# |      marriage|        60| 685|
# |         going|        60| 686|
# |       foreign|        60| 687|
# |       website|        60| 688|
# |          arts|        60| 689|
# |      carranza|        59| 690|
# |            al|        59| 691|
# |      republic|        59| 692|
# |         earth|        59| 693|
# |      consists|        59| 694|
# |           put|        59| 695|
# |      composed|        59| 696|
# |         prior|        59| 697|
# |        behind|        59| 698|
# |          sold|        59| 699|
# |       theatre|        59| 700|
# |          duke|        59| 701|
# |         cross|        59| 702|
# |     appointed|        59| 703|
# |           far|        58| 704|
# |      platform|        58| 705|
# |        writer|        58| 706|
# |           met|        58| 707|
# |          ucas|        58| 708|
# |       allowed|        58| 709|
# |         coast|        58| 710|
# |           ten|        58| 711|
# |     hawkeagle|        58| 712|
# |         human|        58| 713|
# |        change|        58| 714|
# |         track|        58| 715|
# |        mostly|        57| 716|
# |         cases|        57| 717|
# |          girl|        57| 718|
# |     variation|        57| 719|
# |          term|        57| 720|
# |          rock|        57| 721|
# |           lee|        57| 722|
# |          help|        57| 723|
# |           sea|        57| 724|
# |    particular|        57| 725|
# |          kong|        57| 726|
# |          tour|        57| 727|
# |        likely|        57| 728|
# |        poland|        57| 729|
# |        return|        57| 730|
# |         event|        57| 731|
# |         miles|        57| 732|
# |     completed|        57| 733|
# |       capital|        57| 734|
# |      canadian|        57| 735|
# |       outside|        57| 736|
# |       players|        57| 737|
# |       chicago|        57| 738|
# |        length|        57| 739|
# |         eight|        56| 740|
# |          cast|        56| 741|
# |             ş|        56| 742|
# |      contains|        56| 743|
# |        africa|        56| 744|
# |        empire|        56| 745|
# |        action|        56| 746|
# |    operations|        56| 747|
# |  construction|        56| 748|
# |      numerous|        56| 749|
# |          dame|        56| 750|
# |          gate|        56| 751|
# |          away|        56| 752|
# |     supported|        56| 753|
# |         smith|        56| 754|
# |      williams|        56| 755|
# |        oregon|        56| 756|
# |           det|        56| 757|
# |       working|        56| 758|
# |        fourth|        56| 759|
# |          matt|        56| 760|
# |       thought|        56| 761|
# |     officials|        56| 762|
# |          hill|        56| 763|
# |       stories|        56| 764|
# |       already|        55| 765|
# |          wing|        55| 766|
# |          past|        55| 767|
# |      featured|        55| 768|
# |         turbo|        55| 769|
# |          come|        55| 770|
# |            mm|        55| 771|
# |         start|        55| 772|
# |    previously|        55| 773|
# |        growth|        55| 774|
# |         heart|        55| 775|
# |          fact|        55| 776|
# |          male|        55| 777|
# |       parents|        55| 778|
# |         bands|        55| 779|
# |     countries|        55| 780|
# |      campaign|        55| 781|
# |       station|        55| 782|
# |          edna|        55| 783|
# |        hockey|        55| 784|
# |   constructed|        55| 785|
# |        course|        55| 786|
# |       freeway|        55| 787|
# |        taking|        54| 788|
# |          view|        54| 789|
# |       toronto|        54| 790|
# |             đ|        54| 791|
# |      previous|        54| 792|
# |     currently|        54| 793|
# |            eg|        54| 794|
# |administration|        54| 795|
# |     northwest|        54| 796|
# |      scotland|        54| 797|
# |          ever|        54| 798|
# |          navy|        54| 799|
# |       defined|        54| 800|
# |          pope|        54| 801|
# |       kinnear|        54| 802|
# |         lived|        54| 803|
# |       claimed|        54| 804|
# |        letter|        54| 805|
# |         green|        53| 806|
# |    associated|        53| 807|
# |    foundation|        53| 808|
# |       friends|        53| 809|
# |       effects|        53| 810|
# |      identity|        53| 811|
# |          runs|        53| 812|
# |         shows|        53| 813|
# |       subject|        53| 814|
# |      japanese|        53| 815|
# |     territory|        53| 816|
# |        yellow|        53| 817|
# |          solo|        53| 818|
# |        sonata|        53| 819|
# |       playing|        53| 820|
# |       someone|        53| 821|
# |        daniel|        53| 822|
# |       changed|        53| 823|
# |      academic|        53| 824|
# |        stated|        53| 825|
# |          poet|        53| 826|
# |       whether|        52| 827|
# |          find|        52| 828|
# |         least|        52| 829|
# |           joe|        52| 830|
# |       feature|        52| 831|
# |          lake|        52| 832|
# |        issues|        52| 833|
# |       complex|        52| 834|
# |         month|        52| 835|
# |         voice|        52| 836|
# |      complete|        52| 837|
# |     interview|        52| 838|
# |       results|        52| 839|
# |       primary|        52| 840|
# |     initially|        52| 841|
# |         means|        52| 842|
# |         spent|        52| 843|
# |    publishing|        52| 844|
# |      literary|        52| 845|
# |         birds|        52| 846|
# |         movie|        52| 847|
# |        singer|        52| 848|
# |        online|        52| 849|
# |       natural|        52| 850|
# |        soviet|        52| 851|
# |       systems|        51| 852|
# |        canada|        51| 853|
# |      practice|        51| 854|
# |           key|        51| 855|
# |         ended|        51| 856|
# |       roberts|        51| 857|
# |      catholic|        51| 858|
# |        grimes|        51| 859|
# |       appears|        51| 860|
# |           cup|        51| 861|
# |          mary|        51| 862|
# |       changes|        51| 863|
# |         billy|        51| 864|
# |        racial|        51| 865|
# |       angeles|        51| 866|
# |          vote|        51| 867|
# |        jewish|        51| 868|
# |        oxford|        51| 869|
# |        better|        51| 870|
# |            rd|        51| 871|
# |     tradition|        50| 872|
# |      exegesis|        50| 873|
# |      referred|        50| 874|
# |    conditions|        50| 875|
# |        source|        50| 876|
# |      provided|        50| 877|
# |       brother|        50| 878|
# |      property|        50| 879|
# |          give|        50| 880|
# |        status|        50| 881|
# |        leader|        50| 882|
# |        jersey|        50| 883|
# |         board|        50| 884|
# |       chinese|        49| 885|
# |          rest|        49| 886|
# |           bbc|        49| 887|
# |        vocals|        49| 888|
# |          felt|        49| 889|
# |        golden|        49| 890|
# |       faculty|        49| 891|
# |       mission|        49| 892|
# |        joseph|        49| 893|
# |          nine|        49| 894|
# |         beach|        49| 895|
# |      evidence|        49| 896|
# |      memorial|        49| 897|
# |        police|        49| 898|
# |      cultural|        49| 899|
# |        spread|        49| 900|
# |         bible|        49| 901|
# |        leaves|        49| 902|
# |        spring|        49| 903|
# |     increased|        49| 904|
# |   helicopters|        49| 905|
# |        inside|        49| 906|
# |       abraham|        49| 907|
# |         saint|        49| 908|
# |           cds|        49| 909|
# |       artists|        49| 910|
# |         cover|        49| 911|
# |          lion|        49| 912|
# |         blood|        48| 913|
# |  particularly|        48| 914|
# |         girls|        48| 915|
# |         whole|        48| 916|
# |       covered|        48| 917|
# |      margaret|        48| 918|
# |            ie|        48| 919|
# |       smaller|        48| 920|
# |    individual|        48| 921|
# |       islands|        48| 922|
# |        prince|        48| 923|
# |         video|        48| 924|
# |        helped|        48| 925|
# |         japan|        48| 926|
# |      required|        48| 927|
# |        bureau|        48| 928|
# |           bob|        48| 929|
# |     residents|        48| 930|
# |       variety|        48| 931|
# |        makeup|        48| 932|
# |       earlier|        48| 933|
# |         scene|        48| 934|
# |          talk|        48| 935|
# |      benjamin|        47| 936|
# |       housing|        47| 937|
# |          cars|        47| 938|
# |          crew|        47| 939|
# |        horror|        47| 940|
# |       actress|        47| 941|
# |      positive|        47| 942|
# |    settlement|        47| 943|
# |     newspaper|        47| 944|
# |    discovered|        47| 945|
# |          arms|        47| 946|
# |        recent|        47| 947|
# |       provide|        47| 948|
# |          prey|        47| 949|
# |        placed|        47| 950|
# |    management|        47| 951|
# |          goal|        47| 952|
# |             ä|        47| 953|
# |       ottoman|        47| 954|
# |      ceremony|        47| 955|
# |      location|        47| 956|
# |     influence|        47| 957|
# |         issue|        47| 958|
# |     kathmandu|        47| 959|
# |      services|        47| 960|
# |      formerly|        47| 961|
# |         forms|        47| 962|
# |            ah|        46| 963|
# |         youth|        46| 964|
# |            jr|        46| 965|
# |         stone|        46| 966|
# |       mexican|        46| 967|
# |        listed|        46| 968|
# |          risk|        46| 969|
# |         kings|        46| 970|
# |     cambridge|        46| 971|
# |           car|        46| 972|
# |   householder|        46| 973|
# |      critical|        46| 974|
# |         orbit|        46| 975|
# |             ă|        46| 976|
# |       teacher|        46| 977|
# |     recording|        46| 978|
# |         hours|        46| 979|
# |        comedy|        46| 980|
# |          idea|        46| 981|
# |       student|        46| 982|
# |           jpg|        46| 983|
# |          star|        46| 984|
# |         names|        46| 985|
# |          baby|        46| 986|
# |       article|        46| 987|
# |        appear|        46| 988|
# |        script|        46| 989|
# |    industrial|        45| 990|
# |      campbell|        45| 991|
# |      function|        45| 992|
# |           tax|        45| 993|
# |         prime|        45| 994|
# |      carolina|        45| 995|
# |        linear|        45| 996|
# |            lu|        45| 997|
# |         nolte|        45| 998|
# |          tesh|        45| 999|
# |       finally|        45|1000|
# +--------------+----------+----+
# only showing top 1000 rows
# enter keyword :  love
# Again? (y / n) :   n
# your selected keys is ['love']
# ================ SAVE THE FILTERED DATA ================
# ==========SENTENCE WITH WORD COUNT==========
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Using state  server backend.                                      (0 + 14) / 14]
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Using state  server backend.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.614 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.622 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.629 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.621 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.623 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.630 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.629 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.616 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.625 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.628 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.623 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.643 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.631 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.635 seconds.
# Prefix dict has been built successfully.
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/filtered_bi_data
# ==========SENTENCE WITHOUT OUTLIERS==========
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/bi_sentence_with_statistics
# ==========BI SENTENCES WITH TAGGING==========
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/bi_sentence_with_tagging
# ==========CREATED BIGRAM==========
# ==========CREATED TRIGRAM==========
# ==========CREATED N4 GRAM==========
# ==========CREATED N5 GRAM==========
# ==========MERGED THE NGRAMS==========
# ==========GET NGRAM WITH KEYWORDS ONLY==========
# ==========MARK THE NGRAM WITH KEYWORDS MIDDLE ON IT==========
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/BI_KeyOnlyData
# ==========COMPUTED THE TAG FREQUENCY==========
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/BI_TAG_FREQ
# ==========COMPUTED THE TOKEN FREQUENCY==========
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/BI_TOKEN_FREQ
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/BI_TAG_F
# if disk block error happen, try increase the value of repartition

# %%
if __name__ == "__main__":
    ## arguments the arguments need to be change
    pyspark_bin_path = "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3"
    python_path = "/home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/bin/python39"
    app_name = "social media"
    data_path = "/home/pc/data/parsed_data/2parsed-extract-mswiki.txt"
    hdfs_working_path = "hdfs://10.123.51.78:8020/user/wikipedia/"
    malay_stopword_path = "stopwords-ms.json"
    jieba_replace_csv = "replacement.csv"
    hdfsHost = "hdfs://10.123.51.78"
    hdfsPort = "8020"
    hdfs_working_path_file = "/user/wikipedia/"
    hiveWarehouseDirectory = "hdfs://10.123.51.78:8020/user/hive/warehouse"
    hiveTriftServerAddress = "thrift://g2.bigtop.it:9083"
    want_remove_outliers = False

    
    # %load_ext autoreload
    # %autoreload 2
    import shutil
    import os
    import json
    import findspark
    findspark.init(pyspark_bin_path)
    from FileIO import *
    import utilities as u
    import pyspark
    from Preprocessing import *
    from pyspark.sql import SparkSession
    from DetectLanguage import *
    from LangAgg import *
    from WordCount import *
    from pyspark.sql.window import Window
    from nltk.corpus import stopwords
    from FilterOutliers import *
    from postagChinese import *
    from JiebaTagToStandardTag import *
    from SegmentDataframe import *
    from Alternator import *
    from TokenLanguageReplaceTool import *
    from pyspark.ml.feature import NGram
    from KeyGram import *
    from MiddleKey import *
    from StopwordsFilteringTool import *
    from SeqID import *
    from PosTagBMBI import *
    import matplotlib.pyplot as plt
    import math


    ################################################################################################################
    ## initialize spark session
    os.environ["HADOOP_USER_NAME"] = "hdfs"
    os.environ["PYSPARK_PYTHON"] = python_path
    os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.12:3.3.0 pyspark-shell'
    spark = SparkSession.builder \
        .appName("Spark NLP")\
        .master("local[*]")\
        .config("spark.driver.memory", "70g")\
        .config("spark.sql.warehouse.dir", hiveWarehouseDirectory) \
        .config("spark.sql.catalogImplementation", "hive")\
        .config("hive.metastore.uris", hiveTriftServerAddress) \
        .getOrCreate()
    ################################################################################################################
    ## convert data into avro format
    bm = spark.read.text(data_path).sample(0.05)
    print(bm.count())
    print("================ CONVERTING DATA TO AVRO FORMAT ================")
    write_avro(bm, f"{hdfs_working_path}oriDataBM")
    ################################################################################################################
    ## preprocess data that will affect sentence tokenization
    df = read_avro(spark, f"{hdfs_working_path}oriDataBM")
    pp = pp(df)

    print("================ SAVE THE PREPROCESSED DATA ================")
    write_avro(pp, f"{hdfs_working_path}ppDataBM")
    remove_from_hdfs(f"{hdfs_working_path}oriDataBM")
    # ################################################################################################################
    # ## doing sentence tokenization on the dataset
    df = read_avro(spark, f"{hdfs_working_path}ppDataBM")
    bmSent = get_eng_senDF(df)
    bmSent= bmSent.withColumn("text", explode(bmSent.columns[0])).select("text")

    print("================ SAVE THE SENTENCE TOKENIZE DATA ================")
    write_avro(bmSent, hdfs_working_path+"sent_tokenize_bm.avro")
    remove_from_hdfs(f"{hdfs_working_path}ppDataBM")
    # ################################################################################################################
    # ## preprocessing II
    df = read_avro(spark, f"{hdfs_working_path}sent_tokenize_bm.avro")
    p2 = preprocessing2(df, "text")

    print("================ SAVE THE CLEANED SENTENCE DATA ================")
    write_avro(p2, hdfs_working_path+"p2_bm")
    remove_from_hdfs(f"{hdfs_working_path}sent_tokenize_bm.avro")
    # ################################################################################################################
    # ## preprocessing III
    df = read_avro(spark, f"{hdfs_working_path}p2_bm")
    sen = get_sentence(df, "text").select("text")
    flat = sen.select(flatten(sen.text).alias('text'))
    a = flat.rdd.map(lambda x : (' '.join(x[0]),1)).toDF(["text", "id"]).drop("id")

    print("================ SAVE THE FINAL PROCESS SENTENCE DATA ================")
    write_avro(a, f"{hdfs_working_path}final_process_bm")
    remove_from_hdfs(f"{hdfs_working_path}p2_bm")
    # # ################################################################################################################
    # # ## Word count statistics
    df = read_avro(spark, f"{hdfs_working_path}final_process_bm")
    malayStopWords = set(json.load(open(malay_stopword_path)))
    stopwordsSet = set(stopwords.words('english') + stopwords.words('chinese') ).union(malayStopWords)
    stopWordsRemoval = StopwordsFilteringTool(stopwordsSet)
    nsbm = stopWordsRemoval.get_no_stop_word_df(df, "text")
    wc = \
        nsbm.rdd.flatMap(lambda x : x.text) \
        .map(lambda x : (x,1)).reduceByKey(lambda V1, V2 : V1+V2) \
        .toDF(["word","word_count"])

    wc\
        .select("word","word_count", F.row_number() \
                .over(Window.partitionBy().orderBy(desc(wc['word_count']))) \
                .alias("id")).show(1000)
    # # ################################################################################################################
    # # ## Prompt user to enter the keywords
    # # ## Select topics
    keys = []
    want_choose = True
    while want_choose:
        key = input("enter keyword : ")
        keys.append(key)
        decision = input("Again? (y / n) :  ")
        if not (decision.upper() == 'Y' or decision.upper() == 'YES'):
            want_choose = False
    print("your selected keys is " + str(keys))
    # # ################################################################################################################
    regex = "|".join(keys)
    filtered = df.filter( df.text.rlike(regex))

    print("================ SAVE THE FILTERED DATA ================")
    write_avro(filtered, f"{hdfs_working_path}filtered_bm_data")
    # # ################################################################################################################
    # # ## create sentence word count statistics
    df = read_avro(spark, f"{hdfs_working_path}filtered_bm_data")
    with_statistics = df.withColumn("token", u.tokenize_chineseDF(df.text))
    with_statistics = with_statistics.withColumn("length", size(with_statistics.token))
    df = with_statistics.select("text", "length")

    print("==========SENTENCE WITH WORD COUNT==========")
    write_avro(df, hdfs_working_path+"bm_sentence_with_statistics")
    remove_from_hdfs(hdfs_working_path+"filtered_bm_data")
    # # ################################################################################################################
    # # ## remove the outliers
    s = read_avro(spark, hdfs_working_path+"bm_sentence_with_statistics")

    if want_remove_outliers:
        s = s.coalesce(74)
        sC = s.select(s.length)
        sC.toPandas().plot.box()
        plt.show()
        s_detect = find_outliers(s)
        noS = s_detect.filter((s_detect.total_outliers < 1)  & (s_detect.length > 3))
        sC = noS.select(noS.length)
        sC.toPandas().plot.box()
        plt.show()

        print("==========SENTENCE WITHOUT OUTLIERS==========")
    else:
        noS = s
    write_avro(noS, hdfs_working_path+"bm_sentence_without_out")
    remove_from_hdfs(hdfs_working_path+"bm_sentence_with_statistics")
    # ################################################################################################################
    # ## pos tag
    df = read_avro(spark, hdfs_working_path+"bm_sentence_without_out")
    df = assign_id_column(df)
    write_avro(df, hdfs_working_path+"bm_with_id")
    df = read_avro(spark, hdfs_working_path+"bm_with_id")

    numberOfRows = df.count()
    splitInto = math.ceil(df.count()/1000)
    segments = get_segments(df, splitInto)



    # split to smaller file to easier processing
    for i in range(splitInto):
        print("write " + str(i))
        write_avro(segments[i].select("text"), f"{hdfs_working_path}IN/{i}")
        print("LEN = " + str(segments[i].count()))

    print(f"the file is splitted into {splitInto} files to ease the prcessing")


    for i in range(splitInto):
        df = read_avro(spark, f"{hdfs_working_path}IN/{i}")
        df.show(5, False)
        tag = df.withColumn("tag", posUDF(df.text))
        write_avro(tag, f"{hdfs_working_path}OUT/{i}")
        df.unpersist()
        print("done execution !")    

        remove_from_hdfs(f"{hdfs_working_path}IN")

    ## merge the file to one and remove the out directory
    alt = Alternator()


    for i in range(splitInto):
        if i == 0:
            merge = read_avro(spark, f"{hdfs_working_path}OUT/{i}")
            write_avro(merge, f"{hdfs_working_path}Merge/{alt.num}")
        else:
            merge = read_avro(spark, f"{hdfs_working_path}Merge/{alt.num}")
            df = read_avro(spark, f"{hdfs_working_path}OUT/{i}")
            union = unionAll(merge, df)
            alt.alternate()
            write_avro(union, f"{hdfs_working_path}Merge/{alt.num}")
            remove_from_hdfs(f"{hdfs_working_path}Merge/{alt.get_alternate()}")

    remove_from_hdfs(f"{hdfs_working_path}OUT")
    df = read_avro(spark, f"{hdfs_working_path}Merge/{alt.num}")
    df.show(10, False)
    # ################################################################################################################
    # Standardize the format
    df = df.rdd.map(lambda x : (x.text, x.tag[0], x.tag[1])).\
            toDF(["original","token","tag"])
    write_avro(df, f"{hdfs_working_path}BM_tokenAndTag")
    # ################################################################################################################
    ## create n-gram
    a = read_avro(spark, hdfs_working_path+"BM_tokenAndTag")
    a = a.repartition(60)
    a= a.withColumn("sentence_id", F.monotonically_increasing_id())
    a = a.rdd.map(lambda x : (x.sentence_id," ".join(x.token), x.token, x.tag)).toDF(["sentence_id", "original","token","tag"])
    write_avro(a, hdfs_working_path+"bm_sentence_with_tagging_format")
    remove_from_hdfs(hdfs_working_path+"BM_tokenAndTag")
    # ################################################################################################################
    a = read_avro(spark, hdfs_working_path+"bm_sentence_with_tagging_format")
    # ################################################################################################################
    # ## bigram
    tokenNgram =NGram(n=2, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=2, inputCol="tag", outputCol="tag_gram")
    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)
    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))

    print("==========CREATED BIGRAM==========")
    write_avro(t, hdfs_working_path+"BM_N2_GRAM")
    # ################################################################################################################
    # ## trigram
    tokenNgram =NGram(n=3, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=3, inputCol="tag", outputCol="tag_gram")

    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)

    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


    print("==========CREATED TRIGRAM==========")
    write_avro(t, hdfs_working_path+"BM_N3_GRAM")
    # ################################################################################################################
    ## n4 gram
    tokenNgram =NGram(n=4, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=4, inputCol="tag", outputCol="tag_gram")

    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)

    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


    print("==========CREATED N4 GRAM==========")
    write_avro(t, hdfs_working_path+"BM_N4_GRAM")
    # ################################################################################################################
    ## n5 gram
    tokenNgram =NGram(n=5, inputCol="token", outputCol="token_gram")
    tagNgram =NGram(n=5, inputCol="tag", outputCol="tag_gram")

    n2 = tokenNgram.transform(a)
    n2 = tagNgram.transform(n2)

    t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
    .select("sentence_id", "original", "tag","token", F.posexplode(col("tmp")))\
    .select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


    print("==========CREATED N5 GRAM==========")
    write_avro(t, hdfs_working_path+"BM_N5_GRAM")
    # ################################################################################################################
    # ## merge ngram
    n2 = read_avro(spark, hdfs_working_path+"BM_N2_GRAM")
    n3 = read_avro(spark, hdfs_working_path+"BM_N3_GRAM")
    n4 = read_avro(spark, hdfs_working_path+"BM_N4_GRAM")
    n5 = read_avro(spark, hdfs_working_path+"BM_N5_GRAM")


    n2 = n2.withColumn("gram_type", lit(2))
    n3 = n3.withColumn("gram_type", lit(3))
    n4 = n4.withColumn("gram_type", lit(4))
    n5 = n5.withColumn("gram_type", lit(5))


    merge = unionAll(n2, n3, n4, n5)

    print("==========MERGED THE NGRAMS==========")
    write_avro(merge, hdfs_working_path+"BM_MERGE_GRAM")
    # ################################################################################################################
    # ## gram frequency statistics
    # ## Tag frequency
    # ################################################################################################################
    # ## filter n gram with key words
    df = read_avro(spark, hdfs_working_path+"BM_MERGE_GRAM")
    keys = set(keys)
    keyGramFilter = KeyGram(keys)
    withKeyOnly = keyGramFilter.getDFwithKeywordsOnly(df)

    print("==========GET NGRAM WITH KEYWORDS ONLY==========")
    write_avro(withKeyOnly, f"{hdfs_working_path}BM_KeyOnlyData")
    # ################################################################################################################
    # create the column to identify whether keyword at middle
    df = read_avro(spark,  f"{hdfs_working_path}BM_KeyOnlyData")
    mid = MiddleKey(keys)
    withMiddleFlag = df.withColumn("middle_key", mid.middleUDF(df.gram_type, df.token_gram))

    print("==========MARK THE NGRAM WITH KEYWORDS MIDDLE ON IT==========")
    write_avro(withMiddleFlag, f"{hdfs_working_path}BM_MiddleFlagData")
    remove_from_hdfs(f"{hdfs_working_path}BM_KeyOnlyData")
    # ################################################################################################################
    # ## Frequency statistics
    # ## tag frequency
    df = read_avro(spark,  f"{hdfs_working_path}BM_MiddleFlagData")
    tagFreq = df.groupBy("tag_gram").count().withColumnRenamed("count", "tag_gram_f")
    write_avro(tagFreq, hdfs_working_path+"BM_TAG_FREQ")
    tagFreq = read_avro(spark, hdfs_working_path+"BM_TAG_FREQ")
    withtagFBI = df.join(tagFreq, df.tag_gram == tagFreq.tag_gram).drop(tagFreq.tag_gram)

    print("==========COMPUTED THE TAG FREQUENCY==========")
    write_avro(withtagFBI, hdfs_working_path+"BM_TAG_F")
    remove_from_hdfs(hdfs_working_path+"BM_TAG_FREQ")
    # ################################################################################################################
    # ## Token frequency
    df = read_avro(spark, hdfs_working_path+"BM_TAG_F")
    bitokenFreq = df.groupBy("token_gram").count().withColumnRenamed("count", "token_gram_f")
    write_avro(bitokenFreq, hdfs_working_path+"BM_TOKEN_FREQ")
    tokenFreq = read_avro(spark, hdfs_working_path+"BM_TOKEN_FREQ")
    biwithTokF = df.join(tokenFreq, df.token_gram == tokenFreq.token_gram).drop(tokenFreq.token_gram)

    print("==========COMPUTED THE TOKEN FREQUENCY==========")
    write_avro(biwithTokF, hdfs_working_path+"BM_TOKEN_F")
    remove_from_hdfs(hdfs_working_path+"BM_TOKEN_FREQ")
    remove_from_hdfs(hdfs_working_path+"BM_TAG_F")
    # ################################################################################################################
    # ## Table Normalization
    # ## Gram table
    df = read_avro(spark, hdfs_working_path+"BM_TOKEN_F")
    df = df.repartition(800)
    gram_table = df.select("sentence_id", "pos", "token_gram", "token_gram_f", "tag_gram", "tag_gram_f", "gram_type", "containsKey", "middle_key")
    gram_table = gram_table.withColumn("uniqueID", monotonically_increasing_id())
    write_avro(gram_table, hdfs_working_path+"BM_GRAM_TABLE")
    # ################################################################################################################
    # ## Source Table
    originalSentence  = df.dropDuplicates((['sentence_id'])).select("sentence_id", "original", "tag", "token")
    originalSentence = originalSentence.repartition(800)
    print("if disk block error happen, try increase the value of repartition")
    originalSentence = originalSentence.withColumn("uniqueID", monotonically_increasing_id())
    write_avro(originalSentence, hdfs_working_path+"BM_SOURCE_TABLE")
    # ################################################################################################################
    # ## Into Hive
    gram_table = read_avro(spark, hdfs_working_path+"BM_GRAM_TABLE")
    original_table = read_avro(spark, hdfs_working_path+"BM_SOURCE_TABLE")

    spark.sql("create database if not exists wikipedia_db;")
    spark.sql("use wikipedia_db;")
    spark.sql("drop table if exists gram_table_ms;")
    spark.sql("drop table if exists source_data_ms;")


    gram_table.write\
    .format("orc") \
    .mode("overwrite") \
    .saveAsTable("wikipedia_db.gram_table_ms")


    original_table.write\
    .format("orc") \
    .mode("overwrite") \
    .saveAsTable("wikipedia_db.source_data_ms")

    # ################################################################################################################
    # ## Analytics
    # # analytics : Top 10 Common Pos Pattern
    Q="""
    select
        distinct tag_gram,
        tag_gram_f
    from
        gram_table_ms
    order by
        tag_gram_f DESC limit 10;
    """

    SMPos = spark.sql(Q).toPandas()

    fig, ax = plt.subplots(1,1,figsize=(15,5))

    x = SMPos['tag_gram'][:10].tolist()
    y = SMPos['tag_gram_f'][:10].tolist()
    ax.barh(x,y)
    ax.set_title('Top 10 Most Common POS Patterns in Wikipedia Malay')
    for index, value in enumerate(y):
        ax.text(value, index,
                 str(value))
    ax.invert_yaxis()

    import shutil
    try:
        shutil.rmtree("visualization")
    except:
        pass
    
    plt.savefig('visualization/top10POSPattern', dpi=300, bbox_inches='tight')
    # ################################################################################################################
    # ## Analytics
    # # analytics : Top 10 Common Token Pattern
    Q="""
    select
        distinct token_gram,
        token_gram_f
    from
        gram_table_ms
    order by
        token_gram_f DESC limit 10;
    """

    SMtok = spark.sql(Q).toPandas()

    fig, ax = plt.subplots(1,1,figsize=(15,5))

    x = SMtok['token_gram'][:10].tolist()
    y = SMtok['token_gram_f'][:10].tolist()
    ax.barh(x,y)
    ax.set_title('Top 10 Most Common Token Patterns in Wikipedia Malay')
    for index, value in enumerate(y):
        ax.text(value, index,
                 str(value))
    ax.invert_yaxis()

    plt.savefig('visualization/top10tokenPattern', dpi=300, bbox_inches='tight')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 35676
# ================ CONVERTING DATA TO AVRO FORMAT ================
# ================ SAVE THE PREPROCESSED DATA ================
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/python39/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ================ SAVE THE SENTENCE TOKENIZE DATA ================
# KeyboardInterrupt
#
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 43878)
# Traceback (most recent call last):
#   File "/opt/python39/lib/python3.9/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/python39/lib/python3.9/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/python39/lib/python3.9/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/python39/lib/python3.9/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/python/pyspark/accumulators.py", line 281, in handle
#     poll(accum_updates)
#   File "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/python/pyspark/accumulators.py", line 253, in poll
#     if func():
#   File "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/python/pyspark/accumulators.py", line 257, in accum_updates
#     num_updates = read_int(self.rfile)
#   File "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3/python/pyspark/serializers.py", line 595, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------

# %%
## arguments
pyspark_bin_path = "/home/pc/TestJupyter/opt/spark-3.3.0/spark-3.3.0-bin-hadoop3"
python_path = "/home/pc/TestJupyter/opt/spark-3.3.0/venv-spark/bin/python39"
app_name = "wikipedia chinese"
data_path = "/home/pc/data/parsed_data/3parsed-extract-zhwiki.txt"
hdfs_working_path = "hdfs://10.123.51.78:8020/user/wikipedia/"
malay_stopword_path = "/home/pc/Assignment/node_modules/stopwords-ms/stopwords-ms.json"
jieba_replace_csv = "/home/pc/Assignment/SocialMedia/Main/replacement.csv"
hdfsHost = "hdfs://10.123.51.78"
hdfsPort = "8020"
hdfs_working_path_file = "/user/wikipedia/"
hiveWarehouseDirectory = "hdfs://10.123.51.78:8020/user/hive/warehouse"
hiveTriftServerAddress = "thrift://g2.bigtop.it:9083"


# %load_ext autoreload
# %autoreload 2
import shutil
import os
import json
import findspark
findspark.init(pyspark_bin_path)
from FileIO import *
import utilities as u
import pyspark
from Preprocessing import *
from pyspark.sql import SparkSession
from DetectLanguage import *
from LangAgg import *
from WordCount import *
from pyspark.sql.window import Window
from nltk.corpus import stopwords
from FilterOutliers import *
from postagChinese import *
from JiebaTagToStandardTag import *
from SegmentDataframe import *
from PosTagBMBI import *
from Alternator import *
from TokenLanguageReplaceTool import *
from pyspark.ml.feature import NGram
from KeyGram import *
from MiddleKey import *
from StopwordsFilteringTool import *
from ChineseSentTokenize import *
import matplotlib.pyplot as plt
import math


# ################################################################################################################
## initialize spark session
os.environ["HADOOP_USER_NAME"] = "hdfs"
os.environ["PYSPARK_PYTHON"] = python_path
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.12:3.3.0 pyspark-shell'


spark = SparkSession.builder \
    .appName("Spark NLP")\
    .master("local[*]")\
    .config("spark.driver.memory", "70g")\
    .config("spark.sql.warehouse.dir", hiveWarehouseDirectory) \
    .config("spark.sql.catalogImplementation", "hive")\
    .config("hive.metastore.uris", hiveTriftServerAddress) \
    .getOrCreate()


# ################################################################################################################
# ## convert data into avro format
bi = spark.read.text(data_path).sample(0.001)
print("================ CONVERTING DATA TO AVRO FORMAT ================")
write_avro(bi, f"{hdfs_working_path}oriDataBC")
# ################################################################################################################
# ## preprocess data that will affect sentence tokenization
df = read_avro(spark, f"{hdfs_working_path}oriDataBC")
df = df.repartition(60)

pp = pp(df)

print("================ SAVE THE PREPROCESSED DATA ================")
write_avro(pp, f"{hdfs_working_path}ppDataBC")
remove_from_hdfs(f"{hdfs_working_path}oriDataBC")
# ################################################################################################################
# ## doing sentence tokenization on the dataset
df = read_avro(spark, f"{hdfs_working_path}ppDataBC")
df = df.repartition(60)

chiSent = get_df_chiSen(df)
chiSent = chiSent.withColumn("text", explode(chiSent.columns[0]))

print("================ SAVE THE SENTENCE TOKENIZE DATA ================")
write_avro(chiSent, hdfs_working_path+"bc_sent_tokenize.avro")
remove_from_hdfs(f"{hdfs_working_path}ppDataBC")
# ################################################################################################################
## preprocessing II
df = read_avro(spark, f"{hdfs_working_path}bc_sent_tokenize.avro")
df = df.repartition(60)

p2 = preprocessing2(df, "text")

print("================ SAVE THE CLEANED SENTENCE DATA ================")
write_avro(p2, hdfs_working_path+"p2_bc")
remove_from_hdfs(f"{hdfs_working_path}bc_sent_tokenize.avro")
# ################################################################################################################
# ## preprocessing III
df = read_avro(spark, f"{hdfs_working_path}p2_bc")
df = df.repartition(60)
sen = get_sentence(df, "text").select("text")
flat = sen.select(flatten(sen.text).alias('text'))
a = flat.rdd.map(lambda x : (' '.join(x[0]),1)).toDF(["text", "id"]).drop("id")

print("================ SAVE THE FINAL PROCESS SENTENCE DATA ================")
write_avro(a, f"{hdfs_working_path}final_process_bc")
remove_from_hdfs(f"{hdfs_working_path}p2_bc")
# ################################################################################################################
# ## Word count statistics
malayStopWords = set(json.load(open(malay_stopword_path)))
stopwordsSet = set(stopwords.words('english') + stopwords.words('chinese') ).union(malayStopWords)

df = read_avro(spark, f"{hdfs_working_path}final_process_bc")
df = df.repartition(60)

stopWordsRemoval = StopwordsFilteringTool(stopwordsSet)

nsbi = stopWordsRemoval.get_no_stop_word_df(df, "text")

wc = \
    nsbi.rdd.flatMap(lambda x : x.text) \
    .map(lambda x : (x,1)).reduceByKey(lambda V1, V2 : V1+V2) \
    .toDF(["word","word_count"])

wc\
    .select("word","word_count", F.row_number() \
            .over(Window.partitionBy().orderBy(desc(wc['word_count']))) \
            .alias("id")).show(1000)
# ################################################################################################################
# ## Prompt user to enter the keywords
# ## Select topics
keys = []
want_choose = True
while want_choose:
    key = input("enter keyword : ")
    keys.append(key)
    decision = input("Again? (y / n) :  ")
    if not (decision.upper() == 'Y' or decision.upper() == 'YES'):
        want_choose = False
print("your selected keys is " + str(keys))
# ################################################################################################################
regex = "|".join(keys)
filtered = df.filter( df.text.rlike(regex))

print("================ SAVE THE FILTERED DATA ================")
write_avro(filtered, f"{hdfs_working_path}filtered_bc_data")
# ################################################################################################################
# ## create sentence word count statistics
df = read_avro(spark, f"{hdfs_working_path}filtered_bc_data")
df = df.repartition(60)
with_statistics = df.withColumn("token", u.tokenize_chineseDF(df.text))
with_statistics = with_statistics.withColumn("length", size(with_statistics.token))
df = with_statistics.select("text", "length")

print("==========SENTENCE WITH WORD COUNT==========")
write_avro(df, hdfs_working_path+"bc_sentence_with_statistics")
remove_from_hdfs(hdfs_working_path+"filtered_bc_data")
# ################################################################################################################
# ## remove the outliers
s = read_avro(spark, hdfs_working_path+"bc_sentence_with_statistics")
s = s.repartition(60)
s = s.coalesce(74)
sC = s.select(s.length)
sC.toPandas().plot.box()
plt.show()
s_detect = find_outliers(s)
noS = s_detect.filter((s_detect.total_outliers < 1)  & (s_detect.length > 3))
sC = noS.select(noS.length)
sC.toPandas().plot.box()
plt.show()

print("==========SENTENCE WITHOUT OUTLIERS==========")
write_avro(noS, hdfs_working_path+"bc_sentence_without_out")
remove_from_hdfs(hdfs_working_path+"bc_sentence_with_statistics")
# ################################################################################################################
# ## pos tag
df = read_avro(spark, hdfs_working_path+"bc_sentence_without_out")
df = df.repartition(60)
chineseTag = df.withColumn("tag", udfTagChinese(df.text))

chineseTag = chineseTag.rdd.map(lambda x : (x.text, x.tag[0], x.tag[1])).\
        toDF(["original","token","tag"])

print("========== SENTENCES WITH TAGGING==========")
write_avro(chineseTag, hdfs_working_path+"bc_sentence_with_tagging")
# ################################################################################################################
## create n-gram
a = read_avro(spark, hdfs_working_path+"bc_sentence_with_tagging")
a = a.repartition(60)
a= a.withColumn("sentence_id", F.monotonically_increasing_id())


a = a.rdd.map(lambda x : (x.sentence_id," ".join(x.token), x.token, x.tag)).toDF(["sentence_id", "original","token","tag"])
write_avro(a, hdfs_working_path+"bc_sentence_with_tagging_format")
remove_from_hdfs(hdfs_working_path+"bc_sentence_with_tagging")
# ################################################################################################################

a = read_avro(spark, hdfs_working_path+"bc_sentence_with_tagging_format")
a = a.repartition(60)

# ################################################################################################################
# ## bigram
tokenNgram =NGram(n=2, inputCol="token", outputCol="token_gram")
tagNgram =NGram(n=2, inputCol="tag", outputCol="tag_gram")
n2 = tokenNgram.transform(a)
n2 = tagNgram.transform(n2)
t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
.select("sentence_id", "original", "tag","token", posexplode(col("tmp")))\
.select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))

print("==========CREATED BIGRAM==========")
write_avro(t, hdfs_working_path+"BC_N2_GRAM")
# ################################################################################################################
# ## trigram
tokenNgram =NGram(n=3, inputCol="token", outputCol="token_gram")
tagNgram =NGram(n=3, inputCol="tag", outputCol="tag_gram")

n2 = tokenNgram.transform(a)
n2 = tagNgram.transform(n2)

t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
.select("sentence_id", "original", "tag","token", posexplode(col("tmp")))\
.select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


print("==========CREATED TRIGRAM==========")
write_avro(t, hdfs_working_path+"BC_N3_GRAM")
# ################################################################################################################
# ## n4 gram
tokenNgram =NGram(n=4, inputCol="token", outputCol="token_gram")
tagNgram =NGram(n=4, inputCol="tag", outputCol="tag_gram")

n2 = tokenNgram.transform(a)
n2 = tagNgram.transform(n2)

t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
.select("sentence_id", "original", "tag","token", posexplode(col("tmp")))\
.select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


print("==========CREATED N4 GRAM==========")
write_avro(t, hdfs_working_path+"BC_N4_GRAM")
# ################################################################################################################
# ## n5 gram
tokenNgram =NGram(n=5, inputCol="token", outputCol="token_gram")
tagNgram =NGram(n=5, inputCol="tag", outputCol="tag_gram")

n2 = tokenNgram.transform(a)
n2 = tagNgram.transform(n2)

t = n2.withColumn("tmp", arrays_zip("token_gram", "tag_gram"))\
.select("sentence_id", "original", "tag","token", posexplode(col("tmp")))\
.select("sentence_id", "original", "tag", "token", "pos", col("col.token_gram"), col("col.tag_gram"))


print("==========CREATED N5 GRAM==========")
write_avro(t, hdfs_working_path+"BC_N5_GRAM")
# ################################################################################################################
# ## merge ngram
n2 = read_avro(spark, hdfs_working_path+"BC_N2_GRAM")
n3 = read_avro(spark, hdfs_working_path+"BC_N3_GRAM")
n4 = read_avro(spark, hdfs_working_path+"BC_N4_GRAM")
n5 = read_avro(spark, hdfs_working_path+"BC_N5_GRAM")


n2 = n2.withColumn("gram_type", lit(2))
n3 = n3.withColumn("gram_type", lit(3))
n4 = n4.withColumn("gram_type", lit(4))
n5 = n5.withColumn("gram_type", lit(5))


merge = unionAll(n2, n3, n4, n5)

print("==========MERGED THE NGRAMS==========")
write_avro(merge, hdfs_working_path+"BC_MERGE_GRAM")
# ################################################################################################################
# ## gram frequency statistics
# ## Tag frequency
# ################################################################################################################
# ## filter n gram with key words
df = read_avro(spark, hdfs_working_path+"BC_MERGE_GRAM")
df = df.repartition(60)
keys = set(keys)
keyGramFilter = KeyGram(keys)
withKeyOnly = keyGramFilter.getDFwithKeywordsOnly(df)

print("==========GET NGRAM WITH KEYWORDS ONLY==========")
write_avro(withKeyOnly, f"{hdfs_working_path}BC_KeyOnlyData")
# ################################################################################################################
# # create the column to identify whether keyword at middle
df = read_avro(spark,  f"{hdfs_working_path}BC_KeyOnlyData")
df = df.repartition(60)

mid = MiddleKey(keys)
withMiddleFlag = df.withColumn("middle_key", mid.middleUDF(df.gram_type, df.token_gram))

print("==========MARK THE NGRAM WITH KEYWORDS MIDDLE ON IT==========")
write_avro(withMiddleFlag, f"{hdfs_working_path}BC_MiddleFlagData")
remove_from_hdfs(f"{hdfs_working_path}BC_KeyOnlyData")
# ################################################################################################################
# ## Frequency statistics
# ## tag frequency
df = read_avro(spark,  f"{hdfs_working_path}BC_MiddleFlagData")
df = df.repartition(60)
tagFreq = df.groupBy("tag_gram").count().withColumnRenamed("count", "tag_gram_f")
write_avro(tagFreq, hdfs_working_path+"BC_TAG_FREQ")
tagFreq = read_avro(spark, hdfs_working_path+"BC_TAG_FREQ")
withtagFBI = df.join(tagFreq, df.tag_gram == tagFreq.tag_gram).drop(tagFreq.tag_gram)

print("==========COMPUTED THE TAG FREQUENCY==========")
write_avro(withtagFBI, hdfs_working_path+"BC_TAG_F")
remove_from_hdfs(hdfs_working_path+"BC_TAG_FREQ")
# ################################################################################################################
# ## Token frequency
df = read_avro(spark, hdfs_working_path+"BC_TAG_F")
df = df.repartition(60)
bitokenFreq = df.groupBy("token_gram").count().withColumnRenamed("count", "token_gram_f")
write_avro(bitokenFreq, hdfs_working_path+"BC_TOKEN_FREQ")
tokenFreq = read_avro(spark, hdfs_working_path+"BC_TOKEN_FREQ")
biwithTokF = df.join(tokenFreq, df.token_gram == tokenFreq.token_gram).drop(tokenFreq.token_gram)

print("==========COMPUTED THE TOKEN FREQUENCY==========")
write_avro(biwithTokF, hdfs_working_path+"BC_TOKEN_F")
remove_from_hdfs(hdfs_working_path+"BC_TOKEN_FREQ")
remove_from_hdfs(hdfs_working_path+"BC_TAG_F")
# ################################################################################################################
## Table Normalization
## Gram table
df = read_avro(spark, hdfs_working_path+"BC_TOKEN_F")
df = df.repartition(10)
gram_table = df.select("sentence_id", "pos", "token_gram", "token_gram_f", "tag_gram", "tag_gram_f", "gram_type", "containsKey", "middle_key")
gram_table = gram_table.withColumn("uniqueID", monotonically_increasing_id())
write_avro(gram_table, hdfs_working_path+"BC_GRAM_TABLE")
# ################################################################################################################
## Source Table
originalSentence  = df.dropDuplicates((['sentence_id'])).select("sentence_id", "original", "tag", "token")
originalSentence = originalSentence.repartition(800)
print("if disk block error happen, try increase the value of repartition")
originalSentence = originalSentence.withColumn("uniqueID", monotonically_increasing_id())
write_avro(originalSentence, hdfs_working_path+"BC_SOURCE_TABLE")
# ################################################################################################################
## Into Hive
gram_table = read_avro(spark, hdfs_working_path+"BC_GRAM_TABLE")
original_table = read_avro(spark, hdfs_working_path+"BC_SOURCE_TABLE")

spark.sql("create database if not exists wikipedia_db;")
spark.sql("use wikipedia_db;")
spark.sql("drop table if exists gram_table_zh;")
spark.sql("drop table if exists source_data_zh;")


gram_table.write\
.format("orc") \
.mode("overwrite") \
.saveAsTable("wikipedia_db.gram_table_zh")


original_table.write\
.format("orc") \
.mode("overwrite") \
.saveAsTable("wikipedia_db.source_data_zh")

# ################################################################################################################
## Analytics
# analytics : Top 10 Common Pos Pattern
Q="""
select
    distinct tag_gram,
    tag_gram_f
from
    gram_table_zh
order by
    tag_gram_f DESC limit 10;
"""

SMPos = spark.sql(Q).toPandas()

fig, ax = plt.subplots(1,1,figsize=(15,5))

x = SMPos['tag_gram'][:10].tolist()
y = SMPos['tag_gram_f'][:10].tolist()
ax.barh(x,y)
ax.set_title('Top 10 Most Common POS Patterns in Wikipedia Chinese')
for index, value in enumerate(y):
    ax.text(value, index,
             str(value))
ax.invert_yaxis()

plt.show()
################################################################################################################
## Analytics
# analytics : Top 10 Common Token Pattern
Q="""
select
    distinct token_gram,
    token_gram_f
from
    gram_table_zh
order by
    token_gram_f DESC limit 10;
"""

SMtok = spark.sql(Q).toPandas()

fig, ax = plt.subplots(1,1,figsize=(15,5))

x = SMtok['token_gram'][:10].tolist()
y = SMtok['token_gram_f'][:10].tolist()
ax.barh(x,y)
ax.set_title('Top 10 Most Common Token Patterns in Wikipedia Chinese')
for index, value in enumerate(y):
    ax.text(value, index,
             str(value))
ax.invert_yaxis()

plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ================ CONVERTING DATA TO AVRO FORMAT ================
# ================ SAVE THE PREPROCESSED DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/oriDataBC
# ================ SAVE THE SENTENCE TOKENIZE DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/ppDataBC
# ================ SAVE THE CLEANED SENTENCE DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/bc_sent_tokenize.avro
# ================ SAVE THE FINAL PROCESS SENTENCE DATA ================
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/p2_bc
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.631 seconds.                                 (0 + 20) / 60]
# Prefix dict has been built successfully.
# Loading model cost 0.633 seconds.
# Loading model cost 0.633 seconds.
# Prefix dict has been built successfully.
# Prefix dict has been built successfully.
# Loading model cost 0.634 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.636 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.636 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.638 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.638 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.639 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.639 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.639 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.640 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.640 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.640 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.641 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.644 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.646 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.649 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.649 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.712 seconds.
# Prefix dict has been built successfully.
# Building prefix dict from the default dictionary ...              (4 + 20) / 60]
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...              (8 + 20) / 60]
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...             (20 + 20) / 60]
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.669 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.655 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.662 seconds.
# Loading model cost 0.684 seconds.
# Prefix dict has been built successfully.
# Prefix dict has been built successfully.
# Loading model cost 0.599 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.608 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.611 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.614 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.615 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.613 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.607 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.634 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.615 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.620 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.633 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.636 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.645 seconds.
# Prefix dict has been built successfully.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.624 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.637 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.622 seconds.                                (21 + 20) / 60]
# Prefix dict has been built successfully.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...             (23 + 20) / 60]
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model cost 0.608 seconds.====>                           (29 + 20) / 60]
# Prefix dict has been built successfully.
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.593 seconds.
# Prefix dict has been built successfully.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.592 seconds.=====>                          (30 + 20) / 60]
# Prefix dict has been built successfully.
# Loading model cost 0.590 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.599 seconds.
# Prefix dict has been built successfully.
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...             (40 + 20) / 60]
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.869 seconds.===============>                (42 + 18) / 60]
# Prefix dict has been built successfully.
# Loading model cost 0.876 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.874 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.880 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.596 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.637 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.643 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.661 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.607 seconds.==================>             (45 + 15) / 60]
# Prefix dict has been built successfully.
# Loading model cost 0.614 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.606 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.677 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.610 seconds.
# Prefix dict has been built successfully.
# Loading model cost 0.622 seconds.
# Prefix dict has been built successfully.
# 22/10/10 19:40:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/10 19:40:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 22/10/10 19:40:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +--------------+----------+----+
# |          word|word_count|  id|
# +--------------+----------+----+
# |            年|      3989|   1|
# |        年月日|      1613|   2|
# |            月|      1556|   3|
# |            中|      1552|   4|
# |            后|      1079|   5|
# |            人|      1007|   6|
# |          一个|       980|   7|
# |          中国|       970|   8|
# |          行星|       820|   9|
# |        小行星|       793|  10|
# |            族|       785|  11|
# |            时|       784|  12|
# |            星|       759|  13|
# |            上|       722|  14|
# |            日|       701|  15|
# |            会|       546|  16|
# |            曾|       475|  17|
# |          研究|       467|  18|
# |          第一|       456|  19|
# |            猫|       452|  20|
# |          世界|       451|  21|
# |            都|       446|  22|
# |          位于|       433|  23|
# |            雷|       430|  24|
# |            尾|       418|  25|
# |          美国|       418|  26|
# |          日本|       415|  27|
# |          公司|       414|  28|
# |          人口|       406|  29|
# |          政府|       404|  30|
# |            小|       382|  31|
# |            不|       374|  32|
# |          公里|       373|  33|
# |            新|       368|  34|
# |          国家|       365|  35|
# |            王|       364|  36|
# |            大|       364|  37|
# |          眼睛|       362|  38|
# |          母猫|       361|  39|
# |          公猫|       358|  40|
# |          大学|       351|  41|
# |          地区|       331|  42|
# |            叶|       330|  43|
# |          平方|       323|  44|
# |            虎|       323|  45|
# |          导师|       322|  46|
# |            站|       320|  47|
# |          第二|       309|  48|
# |            号|       305|  49|
# |            皮|       304|  50|
# |            毛|       304|  51|
# |            前|       296|  52|
# |          车站|       295|  53|
# |            斑|       290|  54|
# |          社会|       282|  55|
# |          人民|       282|  56|
# |          台湾|       279|  57|
# |            白|       279|  58|
# |            下|       275|  59|
# |            张|       274|  60|
# |          包括|       274|  61|
# |          近地|       273|  62|
# |            天|       272|  63|
# |            李|       271|  64|
# |            米|       269|  65|
# |            高|       267|  66|
# |            已|       263|  67|
# |            名|       263|  68|
# |          母亲|       262|  69|
# |          之间|       260|  70|
# |            影|       257|  71|
# |          香港|       257|  72|
# |          父亲|       256|  73|
# |            还|       256|  74|
# |            亦|       256|  75|
# |          系统|       253|  76|
# |            尔|       251|  77|
# |            羽|       250|  78|
# |          福利|       249|  79|
# |            饰|       248|  80|
# |          第三|       246|  81|
# |            翅|       243|  82|
# |            更|       242|  83|
# |          国际|       241|  84|
# |          面积|       237|  85|
# |        方公里|       236|  86|
# |            军|       236|  87|
# |          代表|       235|  88|
# |      平方公里|       234|  89|
# |            州|       234|  90|
# |            线|       233|  91|
# |            索|       233|  92|
# |          left|       232|  93|
# |          主义|       231|  94|
# |            子|       230|  95|
# |          见习|       230|  96|
# |            陈|       229|  97|
# |        见习生|       227|  98|
# |            使|       226|  99|
# |          小组|       225| 100|
# |          伴侣|       225| 101|
# |         align|       224| 102|
# |          运动|       224| 103|
# |          发展|       223| 104|
# |          法国|       222| 105|
# |            县|       220| 106|
# |          政治|       218| 107|
# |          科罗|       217| 108|
# |          委员|       216| 109|
# |            说|       214| 110|
# |            氏|       214| 111|
# |            风|       213| 112|
# |          提供|       212| 113|
# |          电视|       212| 114|
# |            爪|       211| 115|
# |            云|       210| 116|
# |          工作|       208| 117|
# |            河|       208| 118|
# |          英国|       208| 119|
# |            松|       207| 120|
# |          林肯|       206| 121|
# |            心|       206| 122|
# |          中华|       205| 123|
# |          一种|       205| 124|
# |          列车|       204| 125|
# |            里|       203| 126|
# |          学院|       203| 127|
# |            斯|       203| 128|
# |          电影|       201| 129|
# |            峰|       195| 130|
# |          中央|       194| 131|
# |            鸦|       193| 132|
# |            却|       192| 133|
# |          灰色|       188| 134|
# |          棕色|       188| 135|
# |          行政|       188| 136|
# |            区|       188| 137|
# |          中心|       186| 138|
# |            指|       185| 139|
# |          担任|       184| 140|
# |            德|       184| 141|
# |            掌|       183| 142|
# |            须|       181| 143|
# |            约|       181| 144|
# |            路|       181| 145|
# |          负责|       181| 146|
# |          欧洲|       181| 147|
# |          航空|       180| 148|
# |          关系|       180| 149|
# |            佛|       180| 150|
# |            东|       180| 151|
# |            死|       180| 152|
# |          战士|       180| 153|
# |          参加|       179| 154|
# |            最|       178| 155|
# |          设计|       178| 156|
# |        内贾德|       178| 157|
# |            只|       177| 158|
# |            三|       177| 159|
# |            省|       177| 160|
# |          组织|       177| 161|
# |          期间|       176| 162|
# |            科|       175| 163|
# |            西|       175| 164|
# |          项目|       175| 165|
# |            利|       174| 166|
# |        艾哈迈|       174| 167|
# |          上海|       174| 168|
# |          族长|       174| 169|
# |          发现|       174| 170|
# |            作|       174| 171|
# |      艾哈迈迪|       173| 172|
# |          饰演|       173| 173|
# |          冠军|       173| 174|
# |            足|       172| 175|
# |            两|       172| 176|
# |          球队|       171| 177|
# |          丝绸|       171| 178|
# |          经济|       170| 179|
# |             p|       170| 180|
# |            副|       170| 181|
# |          作品|       170| 182|
# |            型|       168| 183|
# |          足球|       168| 184|
# |          手足|       168| 185|
# |            法|       167| 186|
# |          铁路|       167| 187|
# |            龙|       167| 188|
# |             c|       166| 189|
# |          时间|       165| 190|
# |          成立|       165| 191|
# |            内|       165| 192|
# |          称为|       164| 193|
# |            麦|       163| 194|
# |          德国|       163| 195|
# |            光|       163| 196|
# |            才|       162| 197|
# |            迦|       160| 198|
# |            镇|       159| 199|
# |            很|       159| 200|
# |        世界杯|       158| 201|
# |            明|       158| 202|
# |            原|       158| 203|
# |          总统|       158| 204|
# |            称|       156| 205|
# |            刘|       155| 206|
# |            便|       155| 207|
# |          计划|       155| 208|
# |          儿子|       154| 209|
# |          攻击|       152| 210|
# |          市镇|       151| 211|
# |          战争|       151| 212|
# |          名为|       151| 213|
# |            金|       150| 214|
# |            林|       150| 215|
# |          游戏|       149| 216|
# |          女儿|       149| 217|
# |            道|       149| 218|
# |          太空|       149| 219|
# |          支持|       148| 220|
# |            属|       148| 221|
# |          历史|       147| 222|
# |            长|       147| 223|
# |          年代|       147| 224|
# |          单位|       147| 225|
# |          世纪|       145| 226|
# |            式|       145| 227|
# |          传统|       145| 228|
# |            黄|       145| 229|
# |            梅|       145| 230|
# |          决赛|       145| 231|
# |          白色|       145| 232|
# |          文化|       143| 233|
# |          机车|       143| 234|
# |            飞|       142| 235|
# |          管理|       142| 236|
# |            尼|       141| 237|
# |          澳门|       141| 238|
# |            克|       141| 239|
# |            去|       140| 240|
# |          共和|       139| 241|
# |            马|       139| 242|
# |          人物|       138| 243|
# |            集|       138| 244|
# |          拥有|       138| 245|
# |            周|       138| 246|
# |          两个|       138| 247|
# |            再|       138| 248|
# |          正式|       137| 249|
# |          罗斯|       136| 250|
# |          监视|       136| 251|
# |            山|       136| 252|
# |        委员会|       136| 253|
# |            鼻|       136| 254|
# |        共和国|       136| 255|
# |          联合|       136| 256|
# |          发生|       135| 257|
# |          杰克|       135| 258|
# |          学校|       135| 259|
# |          北京|       133| 260|
# |          利亚|       133| 261|
# |          琥珀|       133| 262|
# |          技术|       132| 263|
# |            南|       132| 264|
# |          自由|       131| 265|
# |            成|       131| 266|
# |          离开|       130| 267|
# |          基特|       130| 268|
# |          动词|       130| 269|
# |          时期|       129| 270|
# |          黑色|       129| 271|
# |          战役|       128| 272|
# |          保护|       127| 273|
# |          国人|       126| 274|
# |          音乐|       126| 275|
# |            今|       126| 276|
# |          奥运|       126| 277|
# |          成功|       126| 278|
# |          成员|       126| 279|
# |          一名|       125| 280|
# |          服务|       125| 281|
# |            元|       125| 282|
# |          前往|       125| 283|
# |            安|       124| 284|
# |            花|       124| 285|
# |            师|       124| 286|
# |          参与|       124| 287|
# |            部|       124| 288|
# |        琥珀色|       123| 289|
# |            达|       123| 290|
# |            市|       123| 291|
# |          设有|       123| 292|
# |            穆|       123| 293|
# |             n|       122| 294|
# |          角色|       122| 295|
# |          台北|       122| 296|
# |          一部|       122| 297|
# |            欧|       122| 298|
# |            无|       122| 299|
# |          部队|       121| 300|
# |            律|       121| 301|
# |          有限|       121| 302|
# |          修道|       121| 303|
# |            灰|       121| 304|
# |          最终|       120| 305|
# |            爱|       120| 306|
# |            艾|       120| 307|
# |            田|       119| 308|
# |            强|       119| 309|
# |             g|       119| 310|
# |          首次|       119| 311|
# |            文|       118| 312|
# |          相间|       118| 313|
# |          故事|       118| 314|
# |          官方|       118| 315|
# |            暗|       118| 316|
# |            罗|       117| 317|
# |          主席|       117| 318|
# |          会议|       117| 319|
# |          建立|       116| 320|
# |            仍|       116| 321|
# |            座|       116| 322|
# |          森林|       115| 323|
# |          比赛|       115| 324|
# |          用于|       115| 325|
# |        黑杰克|       115| 326|
# |            池|       115| 327|
# |          活动|       114| 328|
# |          出版|       114| 329|
# |          长老|       114| 330|
# |          国民|       114| 331|
# |          影响|       114| 332|
# |            鹰|       113| 333|
# |            次|       113| 334|
# |          方式|       113| 335|
# |            凯|       113| 336|
# |          制作|       113| 337|
# |            二|       112| 338|
# |          希望|       112| 339|
# |          情况|       112| 340|
# |            共|       112| 341|
# |            圣|       112| 342|
# |          工程|       112| 343|
# |          下辖|       112| 344|
# |            间|       111| 345|
# |          资料|       111| 346|
# |            蕨|       110| 347|
# |          资格|       110| 348|
# |          数据|       110| 349|
# |            诸|       110| 350|
# |            言|       110| 351|
# |          语言|       110| 352|
# |          科学|       109| 353|
# |        修道院|       109| 354|
# |          魔法|       109| 355|
# |          该国|       109| 356|
# |          导致|       109| 357|
# |            非|       109| 358|
# |          第四|       109| 359|
# |          指挥|       109| 360|
# |            派|       109| 361|
# |          道院|       109| 362|
# |            史|       109| 363|
# |            绿|       108| 364|
# |          发行|       108| 365|
# |          来自|       108| 366|
# |            波|       108| 367|
# |            柳|       108| 368|
# |          生活|       108| 369|
# |            分|       108| 370|
# |          黄色|       107| 371|
# |            令|       107| 372|
# |        俄罗斯|       107| 373|
# |          学生|       107| 374|
# |          巴士|       107| 375|
# |          小猫|       107| 376|
# |          建设|       106| 377|
# |          海拔|       106| 378|
# |          司令|       106| 379|
# |          球员|       106| 380|
# |            华|       106| 381|
# |          一只|       106| 382|
# |          选举|       106| 383|
# |          火星|       105| 384|
# |            曼|       105| 385|
# |            点|       105| 386|
# |          系列|       105| 387|
# |            字|       105| 388|
# |          罗马|       105| 389|
# |          民国|       105| 390|
# |            宗|       105| 391|
# |          十二|       104| 392|
# |          命令|       104| 393|
# |            皆|       104| 394|
# |          大利|       104| 395|
# |             x|       104| 396|
# |          议会|       104| 397|
# |          伊朗|       104| 398|
# |          军事|       103| 399|
# |          能力|       103| 400|
# |          教育|       103| 401|
# |          华人|       103| 402|
# |          事件|       103| 403|
# |          女子|       102| 404|
# |          二十|       102| 405|
# |          方向|       102| 406|
# |          男子|       101| 407|
# |             b|       101| 408|
# |          增加|       101| 409|
# |            村|       101| 410|
# |          一位|       101| 411|
# |            制|       101| 412|
# |          铁道|       101| 413|
# |          结束|       101| 414|
# |          全国|       100| 415|
# |            歌|       100| 416|
# |          市场|       100| 417|
# |            棘|       100| 418|
# |          出生|       100| 419|
# |          位置|        99| 420|
# |            总|        99| 421|
# |            国|        99| 422|
# |          高度|        99| 423|
# |    人民共和国|        99| 424|
# |            台|        99| 425|
# |          动画|        99| 426|
# |          独立|        99| 427|
# |            迪|        99| 428|
# |          印度|        99| 429|
# |            万|        98| 430|
# |      有限公司|        98| 431|
# |            卷|        98| 432|
# |          理论|        98| 433|
# |            狮|        98| 434|
# |          阿难|        98| 435|
# |          最佳|        98| 436|
# |            洛|        97| 437|
# |          目的|        97| 438|
# |            语|        97| 439|
# |          控制|        97| 440|
# |          领导|        97| 441|
# |          革命|        97| 442|
# |          密度|        97| 443|
# |            焰|        96| 444|
# |          进攻|        96| 445|
# |            格|        96| 446|
# |          生产|        96| 447|
# |            拉|        96| 448|
# |          第十|        95| 449|
# |          哲学|        95| 450|
# |          学家|        95| 451|
# |          列表|        95| 452|
# |            森|        95| 453|
# |            队|        95| 454|
# |          特别|        95| 455|
# |          将军|        95| 456|
# |          毕业|        94| 457|
# |            铁|        94| 458|
# |          接受|        94| 459|
# |            石|        94| 460|
# |          变化|        94| 461|
# |      人口密度|        94| 462|
# |            杨|        94| 463|
# |          提出|        93| 464|
# |          亚尔|        93| 465|
# |          建筑|        93| 466|
# |          汽车|        93| 467|
# |          生于|        93| 468|
# |            de|        93| 469|
# |中华人民共和国|        92| 470|
# |            恩|        92| 471|
# |            好|        92| 472|
# |      中华人民|        92| 473|
# |          网站|        92| 474|
# |          部长|        92| 475|
# |          国联|        92| 476|
# |            应|        92| 477|
# |            全|        92| 478|
# |          训练|        91| 479|
# |          企业|        91| 480|
# |            未|        91| 481|
# |          相关|        91| 482|
# |          巴西|        91| 483|
# |        西班牙|        91| 484|
# |             é|        90| 485|
# |          北部|        90| 486|
# |          集团|        90| 487|
# |            庄|        90| 488|
# |            藏|        90| 489|
# |          地方|        90| 490|
# |            乡|        90| 491|
# |            诺|        89| 492|
# |          昭和|        89| 493|
# |          驱逐|        89| 494|
# |            毗|        89| 495|
# |            朱|        88| 496|
# |          天津|        88| 497|
# |          节目|        88| 498|
# |          人员|        88| 499|
# |            特|        88| 500|
# |            宫|        88| 501|
# |            沙|        88| 502|
# |            木|        88| 503|
# |            城|        88| 504|
# |            仅|        88| 505|
# |          管辖|        87| 506|
# |            事|        87| 507|
# |          德军|        87| 508|
# |          表现|        87| 509|
# |            曲|        87| 510|
# |          选择|        87| 511|
# |          三军|        87| 512|
# |          结集|        86| 513|
# |          名字|        86| 514|
# |          学名|        86| 515|
# |          有人|        86| 516|
# |            四|        86| 517|
# |             h|        86| 518|
# |            蒋|        86| 519|
# |            五|        85| 520|
# |            想|        85| 521|
# |          形容|        85| 522|
# |          反对|        85| 523|
# |          主任|        85| 524|
# |          医院|        84| 525|
# |          尼亚|        84| 526|
# |            受|        84| 527|
# |          同年|        84| 528|
# |            班|        84| 529|
# |          城市|        84| 530|
# |          联通|        84| 531|
# |          动员|        84| 532|
# |          部族|        84| 533|
# |            生|        84| 534|
# |            跃|        84| 535|
# |          制造|        84| 536|
# |        第三军|        84| 537|
# |            卡|        84| 538|
# |            均|        84| 539|
# |          缓冲|        83| 540|
# |          方法|        83| 541|
# |            常|        83| 542|
# |          道路|        83| 543|
# |            吉|        83| 544|
# |          路线|        83| 545|
# |          工业|        83| 546|
# |          专辑|        83| 547|
# |          民政|        83| 548|
# |          女性|        82| 549|
# |          朋友|        82| 550|
# |            绘|        82| 551|
# |          支援|        82| 552|
# |             r|        82| 553|
# |          医学|        81| 554|
# |            纹|        81| 555|
# |            行|        81| 556|
# |            美|        81| 557|
# |            兰|        81| 558|
# |            余|        81| 559|
# |            布|        81| 560|
# |            立|        81| 561|
# |          形式|        81| 562|
# |          参考|        81| 563|
# |          力量|        80| 564|
# |          漫画|        80| 565|
# |        阿根廷|        80| 566|
# |            届|        80| 567|
# |          采用|        80| 568|
# |          盟军|        80| 569|
# |            et|        80| 570|
# |          根廷|        80| 571|
# |          阿根|        80| 572|
# |          一条|        80| 573|
# |          比丘|        79| 574|
# |        运动员|        79| 575|
# |            纳|        79| 576|
# |            形|        79| 577|
# |            夫|        79| 578|
# |            岁|        79| 579|
# |            蓝|        79| 580|
# |            黑|        79| 581|
# |          乔治|        79| 582|
# |          分布|        79| 583|
# |          显示|        79| 584|
# |            耶|        79| 585|
# |            战|        79| 586|
# |          开发|        78| 587|
# |          模式|        78| 588|
# |          调查|        78| 589|
# |          isbn|        78| 590|
# |          斯特|        78| 591|
# |            版|        78| 592|
# |          月台|        78| 593|
# |          运行|        78| 594|
# |          军团|        77| 595|
# |          陆军|        77| 596|
# |            女|        77| 597|
# |          大陆|        77| 598|
# |      海拔高度|        76| 599|
# |            窝|        76| 600|
# |            奖|        76| 601|
# |          神社|        76| 602|
# |            暴|        76| 603|
# |          拔高|        76| 604|
# |            la|        76| 605|
# |            亚|        76| 606|
# |          推出|        76| 607|
# |          杀死|        76| 608|
# |          文学|        76| 609|
# |            现|        76| 610|
# |          时代|        76| 611|
# |          巫医|        76| 612|
# |           jpg|        76| 613|
# |            伊|        76| 614|
# |          合作|        76| 615|
# |          南部|        75| 616|
# |            雀|        75| 617|
# |          一年|        75| 618|
# |            命|        75| 619|
# |            赛|        75| 620|
# |          唯一|        75| 621|
# |          家庭|        75| 622|
# |            费|        75| 623|
# |          利用|        75| 624|
# |          结构|        75| 625|
# |          该地|        75| 626|
# |            处|        75| 627|
# |          公元|        75| 628|
# |          赛事|        75| 629|
# |          广西|        75| 630|
# |          机场|        75| 631|
# |            宝|        74| 632|
# |          年时|        74| 633|
# |          卡西|        74| 634|
# |         right|        74| 635|
# |            博|        74| 636|
# |            汝|        74| 637|
# |            外|        74| 638|
# |          对手|        74| 639|
# |          部门|        74| 640|
# |            出|        74| 641|
# |          警察|        73| 642|
# |          民主|        73| 643|
# |            脚|        73| 644|
# |          演员|        73| 645|
# |          三个|        73| 646|
# |          文物|        73| 647|
# |          小时|        73| 648|
# |            夏|        73| 649|
# |          联盟|        73| 650|
# |        卡西诺|        73| 651|
# |            入|        73| 652|
# |            口|        73| 653|
# |            莉|        73| 654|
# |            草|        73| 655|
# |            福|        73| 656|
# |          国防|        73| 657|
# |            寿|        73| 658|
# |            位|        73| 659|
# |          姜黄|        72| 660|
# |          设备|        72| 661|
# |          美洲|        72| 662|
# |          网络|        72| 663|
# |          命名|        72| 664|
# |          战车|        72| 665|
# |          进士|        72| 666|
# |          父母|        72| 667|
# |          植物|        72| 668|
# |            正|        72| 669|
# |          当地|        72| 670|
# |          日语|        71| 671|
# |          死亡|        71| 672|
# |          公会|        71| 673|
# |          逻辑|        71| 674|
# |          黑暗|        71| 675|
# |            书|        71| 676|
# |            苏|        71| 677|
# |          标准|        71| 678|
# |            先|        71| 679|
# |          身份|        71| 680|
# |          分为|        71| 681|
# |            志|        71| 682|
# |            蔡|        71| 683|
# |          活用|        71| 684|
# |            鼠|        70| 685|
# |            川|        70| 686|
# |          天文|        70| 687|
# |          内容|        70| 688|
# |          孩子|        70| 689|
# |          多元|        70| 690|
# |            al|        70| 691|
# |             l|        70| 692|
# |          发表|        70| 693|
# |          白相|        70| 694|
# |          名称|        70| 695|
# |            阳|        70| 696|
# |          原本|        70| 697|
# |            营|        70| 698|
# |          包含|        69| 699|
# |            奈|        69| 700|
# |            加|        69| 701|
# |          连接|        69| 702|
# |          功能|        69| 703|
# |          二次|        69| 704|
# |          当选|        69| 705|
# |            莓|        69| 706|
# |          冬青|        69| 707|
# |            希|        69| 708|
# |            瓦|        69| 709|
# |            知|        69| 710|
# |          单曲|        69| 711|
# |          国政|        69| 712|
# |          湘军|        69| 713|
# |             e|        69| 714|
# |            种|        69| 715|
# |          蒙古|        68| 716|
# |            曰|        68| 717|
# |            页|        68| 718|
# |          艺术|        68| 719|
# |            做|        68| 720|
# |            图|        68| 721|
# |          南京|        68| 722|
# |        第一次|        68| 723|
# |            母|        68| 724|
# |          大战|        68| 725|
# |          自强|        68| 726|
# |          透过|        68| 727|
# |            舍|        68| 728|
# |          超过|        67| 729|
# |          业务|        67| 730|
# |            官|        67| 731|
# |          定义|        67| 732|
# |          过程|        67| 733|
# |          作用|        67| 734|
# |            社|        67| 735|
# |          机构|        67| 736|
# |          距离|        67| 737|
# |      中华民国|        67| 738|
# |          国大|        67| 739|
# |            礼|        67| 740|
# |          交通|        66| 741|
# |             á|        66| 742|
# |          十一|        66| 743|
# |          东部|        66| 744|
# |            胡|        66| 745|
# |            兹|        66| 746|
# |          东北|        66| 747|
# |          原因|        66| 748|
# |          新闻|        66| 749|
# |          人类|        66| 750|
# |            红|        66| 751|
# |            北|        66| 752|
# |          兄弟|        66| 753|
# |          选手|        66| 754|
# |            维|        66| 755|
# |          不明|        66| 756|
# |            兴|        66| 757|
# |          合并|        66| 758|
# |            夢|        65| 759|
# |            戒|        65| 760|
# |            男|        65| 761|
# |             z|        65| 762|
# |          自动|        65| 763|
# |          演唱|        65| 764|
# |            计|        65| 765|
# |          飞机|        65| 766|
# |        自强号|        65| 767|
# |            溪|        65| 768|
# |            学|        65| 769|
# |          版本|        65| 770|
# |          协议|        65| 771|
# |          大道|        65| 772|
# |          改变|        65| 773|
# |            旧|        65| 774|
# |          热带|        65| 775|
# |            儿|        65| 776|
# |          大部|        64| 777|
# |          trim|        64| 778|
# |            鱼|        64| 779|
# |          最初|        64| 780|
# |          举办|        64| 781|
# |            太|        64| 782|
# |            蛇|        64| 783|
# |            景|        64| 784|
# |          操作|        64| 785|
# |          基础|        64| 786|
# |             í|        64| 787|
# |            隆|        64| 788|
# |            家|        64| 789|
# |          太平|        64| 790|
# |            画|        64| 791|
# |          西南|        64| 792|
# |          简称|        64| 793|
# |            萨|        64| 794|
# |            帕|        64| 795|
# |            词|        64| 796|
# |        形容词|        63| 797|
# |            氹|        63| 798|
# |          文件|        63| 799|
# |            治|        63| 800|
# |          金光|        63| 801|
# |            夜|        63| 802|
# |          执行|        63| 803|
# |        第二次|        63| 804|
# |            住|        63| 805|
# |            岛|        63| 806|
# |          知识|        63| 807|
# |            见|        63| 808|
# |            巴|        63| 809|
# |            堂|        63| 810|
# |          参谋|        63| 811|
# |          身分|        63| 812|
# |            群|        63| 813|
# |          营地|        63| 814|
# |          风暴|        63| 815|
# |            莱|        63| 816|
# |          规模|        63| 817|
# |          再次|        62| 818|
# |          区域|        62| 819|
# |          概念|        62| 820|
# |            瑞|        62| 821|
# |            普|        62| 822|
# |            吴|        62| 823|
# |          环境|        62| 824|
# |          信息|        62| 825|
# |          十三|        62| 826|
# |            顿|        62| 827|
# |            相|        62| 828|
# |          设立|        62| 829|
# |        总面积|        62| 830|
# |          名单|        62| 831|
# |          事务|        62| 832|
# |            泰|        62| 833|
# |          当中|        62| 834|
# |            义|        62| 835|
# |          大臣|        62| 836|
# |          自治|        61| 837|
# |            泥|        61| 838|
# |            伯|        61| 839|
# |          妹妹|        61| 840|
# |          宠物|        61| 841|
# |            蛾|        61| 842|
# |          创作|        61| 843|
# |            雅|        61| 844|
# |          内阁|        61| 845|
# |          本线|        61| 846|
# |          西亚|        61| 847|
# |            街|        61| 848|
# |            仁|        61| 849|
# |          报告|        61| 850|
# |            银|        61| 851|
# |          类型|        61| 852|
# |          着名|        61| 853|
# |          苏联|        61| 854|
# |          小说|        61| 855|
# |          政区|        61| 856|
# |          联赛|        61| 857|
# |          中共|        61| 858|
# |          不再|        61| 859|
# |            杜|        60| 860|
# |          营运|        60| 861|
# |        行政区|        60| 862|
# |            杀|        60| 863|
# |            武|        60| 864|
# |            郡|        60| 865|
# |            请|        60| 866|
# |          回到|        60| 867|
# |          随后|        60| 868|
# |            町|        60| 869|
# |          会主|        60| 870|
# |            微|        60| 871|
# |          大楼|        60| 872|
# |            寺|        60| 873|
# |            平|        60| 874|
# |          公布|        60| 875|
# |          亚洲|        59| 876|
# |          越南|        59| 877|
# |            朗|        59| 878|
# |          观众|        59| 879|
# |          元年|        59| 880|
# |          青年|        59| 881|
# |          秘密|        59| 882|
# |          涅槃|        59| 883|
# |            升|        59| 884|
# |            车|        59| 885|
# |            获|        59| 886|
# |          儿童|        59| 887|
# |            重|        59| 888|
# |          附属|        59| 889|
# |          行驶|        59| 890|
# |            玛|        59| 891|
# |            项|        59| 892|
# |            驻|        59| 893|
# |      中国联通|        59| 894|
# |          古代|        59| 895|
# |          神宫|        59| 896|
# |          居住|        59| 897|
# |          政策|        59| 898|
# |            厄|        59| 899|
# |            众|        59| 900|
# |          自然|        58| 901|
# |            霜|        58| 902|
# |          尾巴|        58| 903|
# |          一段|        58| 904|
# |          主教|        58| 905|
# |          湖北|        58| 906|
# |        意大利|        58| 907|
# |            帝|        58| 908|
# |            神|        58| 909|
# |          排名|        58| 910|
# |            色|        58| 911|
# |          尊者|        58| 912|
# |        官方网|        58| 913|
# |          记录|        58| 914|
# |          街道|        58| 915|
# |            提|        58| 916|
# |          星族|        58| 917|
# |            鸟|        58| 918|
# |          银行|        58| 919|
# |            带|        58| 920|
# |          锦标|        58| 921|
# |          二年|        57| 922|
# |          广播|        57| 923|
# |          法军|        57| 924|
# |            登|        57| 925|
# |          学习|        57| 926|
# |             k|        57| 927|
# |          喜欢|        57| 928|
# |        宠物猫|        57| 929|
# |          居民|        57| 930|
# |             f|        57| 931|
# |          四年|        57| 932|
# |          共有|        57| 933|
# |          名古|        57| 934|
# |            鲁|        57| 935|
# |          三十|        57| 936|
# |          议员|        57| 937|
# |            含|        57| 938|
# |          机会|        57| 939|
# |            桦|        57| 940|
# |            进|        57| 941|
# |          很多|        57| 942|
# |          共产|        57| 943|
# |            塔|        57| 944|
# |          保守|        56| 945|
# |          商业|        56| 946|
# |            初|        56| 947|
# |            灭|        56| 948|
# |          利多|        56| 949|
# |        名古屋|        56| 950|
# |          东京|        56| 951|
# |        一部分|        56| 952|
# |            雨|        56| 953|
# |          歌曲|        56| 954|
# |            改|        56| 955|
# |          职业|        56| 956|
# |          古屋|        56| 957|
# |          指出|        56| 958|
# |        第一个|        56| 959|
# |          山区|        56| 960|
# |          协会|        56| 961|
# |          帝国|        56| 962|
# |          发布|        56| 963|
# |          速度|        56| 964|
# |          出口|        56| 965|
# |          大会|        56| 966|
# |          开放|        56| 967|
# |            蒂|        56| 968|
# |            泽|        56| 969|
# |          公园|        55| 970|
# |            世|        55| 971|
# |            远|        55| 972|
# |          解放|        55| 973|
# |          赢得|        55| 974|
# |            司|        55| 975|
# |          智慧|        55| 976|
# |            传|        55| 977|
# |            发|        55| 978|
# |            藤|        55| 979|
# |            哥|        55| 980|
# |          十四|        55| 981|
# |            兽|        55| 982|
# |          克特|        55| 983|
# |          三年|        55| 984|
# |          办公|        55| 985|
# |            嘉|        55| 986|
# |            奇|        55| 987|
# |            察|        55| 988|
# |          纪念|        55| 989|
# |          台中|        55| 990|
# |          发动|        55| 991|
# |          城镇|        55| 992|
# |            厚|        55| 993|
# |          主角|        55| 994|
# |          名词|        55| 995|
# |            勒|        55| 996|
# |          哥哥|        55| 997|
# |          巡回|        55| 998|
# |          联邦|        55| 999|
# |          嘉靖|        54|1000|
# +--------------+----------+----+
# only showing top 1000 rows
# enter keyword :  terletak
# Again? (y / n) :   n
# your selected keys is ['terletak']
# ================ SAVE THE FILTERED DATA ================
# ==========SENTENCE WITH WORD COUNT==========
# Deleted hdfs://10.123.51.78:8020/user/wikipedia/filtered_bc_data
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <cell line: 171>()
#     169 sC.toPandas().plot.box()
#     170 plt.show()
# --> 171 s_detect = find_outliers(s)
#     172 noS = s_detect.filter((s_detect.total_outliers < 1)  & (s_detect.length > 3))
#     173 sC = noS.select(noS.length)
#
# File ~/Assignment/Wikipedia/Main/Program/FilterOutliers.py:22, in find_outliers(df)
#      17 Q3 = df.approxQuantile(column,[0.75],relativeError=0)
#      19 # IQR : Inter Quantile Range
#      20 # We need to define the index [0], as Q1 & Q3 are a set of lists., to perform a mathematical operation
#      21 # Q1 & Q3 are defined seperately so as to have a clear indication on First Quantile & 3rd Quantile
# ---> 22 IQR = Q3[0] - Q1[0]
#      24 #selecting the data, with -1.5*IQR to + 1.5*IQR., where param = 1.5 default value
#      25 less_Q1 =  Q1[0] - 1.5*IQR
#
# IndexError: list index out of range
